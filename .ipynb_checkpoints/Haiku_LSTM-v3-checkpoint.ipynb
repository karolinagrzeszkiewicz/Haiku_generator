# %% [markdown]
# # Haiku generator with LSTM

# %% [markdown]
# Haiku dataset https://www.kaggle.com/hjhalani30/haiku-dataset

# %% [markdown]
# # 1. Data preparation and cleaning

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.4.0'

# %%
import matplotlib.pyplot as plt 
import numpy as np 
import os 
import pandas as pd 
import sys
import keras
from keras.models import load_model, Model
from keras.layers import Dense, Activation, Dropout, Input, LSTM, Reshape, Lambda, RepeatVector
from keras.initializers import glorot_uniform
from keras.utils import to_categorical, plot_model
from keras.optimizers import Adam
from keras import backend as K
import tensorflow as tf
import tensorflow_probability as tfp
tf.compat.v1.disable_eager_execution()

# %%
dirname = os.getcwd()
filename = "all_haiku.csv"
path_to_dataset = os.path.join(dirname, filename)
n_examples = 124295
data = pd.read_csv(path_to_dataset, delimiter=',', nrows = n_examples)
nRow, nCol = data.shape
print(f'There are {nRow} rows and {nCol} columns')

#cols 1-3 are 1st, 2nd, and 3rd lines of the haiku respectively
# Out:
# There are 124295 rows and 6 columns

# %%
data = data.to_numpy()

# %%
#cols 1-3 are 1st, 2nd, and 3rd lines of the haiku respectively

X_1_0 = data[:,1]
X_2_0 = data[:,2]
X_3_0 = data[:,3]

# %%
X_1 = []
X_2 = []
X_3 = []
for i in range(n_examples):
    if type(X_1_0[i]) == str and type(X_2_0[i]) == str and type(X_3_0[i]) == str:
        X_1.append(X_1_0[i])
        X_2.append(X_2_0[i])
        X_3.append(X_3_0[i])

# %%
#clean the data to get rid off "-" etc
#to make it sensitive to lines, maybe we could implement a line break as some symbol e.g. "|" and merge the X's together
punctuation = ['-', '--', '~', '—', '.', ';', ',', ':', '?', '!', '#', '(', ')', '<', '>', '*', '%', '{', '_', ']', '[', '@', '`', '\xa0', '=', '"', '&', '–', '…', '“', '”']

end_of_line = '.'
end_of_haiku = '/'

for i in range(len(X_1)):
    for p in punctuation:
        if p in X_1[i]:
            X_1[i] = X_1[i].replace(p, '')
        if p in X_2[i]:
            X_2[i] = X_2[i].replace(p, '')
        if p in X_3[i]:
            X_3[i] = X_3[i].replace(p, '')
   
    #delete redundant spaces
    if X_1[i][-3:-1] == '   ':
        X_1[i] = X_1[i].replace('   ', '')
    elif X_1[i][-2:-1] == '  ':
        X_1[i] = X_1[i].replace('  ', '')   
    elif X_1[i][-1] == ' ':
        X_1[i] = X_1[i].replace(' ', '')
    
    if X_2[i][-3:-1] == '   ':
        X_2[i] = X_2[i].replace('   ', '')
    elif X_2[i][-2:-1] == '  ':
        X_2[i] = X_2[i].replace('  ', '')   
    elif X_1[i][-1] == ' ':
        X_2[i] = X_2[i].replace(' ', '')
        
    if X_3[i][-3:-1] == '   ':
        X_3[i] = X_1[i].replace('   ', '')
    elif X_3[i][-2:-1] == '  ':
        X_3[i] = X_1[i].replace('  ', '')   
    elif X_3[i][-1] == ' ':
        X_1[i] = X_1[i].replace(' ', '')
    

    
    #X_1[i] += end_of_line
    #X_2[i] += end_of_line
    #X_3[i] += end_of_line
    #X_3[i] += end_of_haiku

# %%
haiku_vec = []
for i in range(len(X_1)):
    haiku = X_1[i].split()
    haiku.append('/')
    for word in X_2[i].split():
        haiku.append(word)
    haiku.append('/')
    for word in X_3[i].split():
        haiku.append(word)
    haiku.append('/')
    haiku_vec.append(haiku)

# %%
haikus = haiku_vec

# %%
short_haikus = []
for i in range(len(haikus)):
    if len(haikus[i]) == 13:
        short_haikus.append(haikus[i])
n_haikus = len(short_haikus)
print(n_haikus)

haikus = short_haikus
# Out:
# 8394

# %%
max_len = 0
for i in range(n_haikus):
    max_len = max(max_len, len(haikus[i]))
    
print(max_len)
# Out:
# 13

# %%
#create words dict

token_index = {}
idx = -1
for haiku in haikus:
    for i in range(len(haiku)):
        if haiku[i] not in token_index:
            token_index[haiku[i]] = idx+1
            idx += 1

# %%
vocab_size = len(token_index)
print(vocab_size)
#our total length is 5x times that
# Out:
# 15889

# %%
token_index
# Out:
# {'fly': 0,
#  'fishing': 1,
#  '/': 2,
#  'the': 3,
#  'sound': 4,
#  'of': 5,
#  'wind': 6,
#  'in': 7,
#  'reel': 8,
#  'visiting': 9,
#  'graves': 10,
#  'stronger': 11,
#  'October': 12,
#  'at': 13,
#  'my': 14,
#  "grandparents'": 15,
#  'early': 16,
#  'morning': 17,
#  'dew': 18,
#  'squeezing': 19,
#  'last': 20,
#  'drop': 21,
#  'from': 22,
#  'teabag': 23,
#  'winter': 24,
#  'roses': 25,
#  'I': 26,
#  'am': 27,
#  'tired': 28,
#  'reading': 29,
#  'between': 30,
#  'lines': 31,
#  'night': 32,
#  'shift': 33,
#  'a': 34,
#  'quick': 35,
#  'break': 36,
#  'to': 37,
#  'look': 38,
#  'stars': 39,
#  'freeze': 40,
#  'warning': 41,
#  'light': 42,
#  'arc': 43,
#  'welder': 44,
#  'brightens': 45,
#  'need': 46,
#  'pee': 47,
#  'once': 48,
#  'we': 49,
#  'hit': 50,
#  'traffic': 51,
#  'out': 52,
#  'fog': 53,
#  'white': 54,
#  'barn': 55,
#  'with': 56,
#  'painted': 57,
#  'butterflies': 58,
#  'distanthurricane': 59,
#  'middle': 60,
#  'rain': 61,
#  'phone': 62,
#  'rings': 63,
#  'waiting': 64,
#  'for': 65,
#  'bus': 66,
#  'street': 67,
#  'dog': 68,
#  'sniffs': 69,
#  'shadow': 70,
#  'windowpane': 71,
#  'end': 72,
#  'finger': 73,
#  'cold': 74,
#  'moon': 75,
#  'taxi': 76,
#  'driver': 77,
#  'tells': 78,
#  'me': 79,
#  'about': 80,
#  'his': 81,
#  'life': 82,
#  'autumn': 83,
#  'looking': 84,
#  'her': 85,
#  'childhood': 86,
#  'photos': 87,
#  'girlfriend': 88,
#  'older': 89,
#  'than': 90,
#  'next': 91,
#  'room': 92,
#  'sick': 93,
#  'mother': 94,
#  'buswindow': 95,
#  'she': 96,
#  'travels': 97,
#  'full': 98,
#  'on': 99,
#  'head': 100,
#  'dogs': 101,
#  'barking': 102,
#  'perhaps': 103,
#  'was': 104,
#  'cat': 105,
#  'other': 106,
#  'line': 107,
#  'red': 108,
#  'lights': 109,
#  'becomes': 110,
#  'sunset': 111,
#  'each': 112,
#  'sip': 113,
#  'bottle': 114,
#  'moonlight': 115,
#  'face': 116,
#  'long': 117,
#  'before': 118,
#  'came': 119,
#  'after': 120,
#  'leave': 121,
#  'blossoming': 122,
#  'pear': 123,
#  'Pearl': 124,
#  'Harbor': 125,
#  'Day': 126,
#  'Koi': 127,
#  'pond': 128,
#  'littered': 129,
#  'fallen': 130,
#  'leaves': 131,
#  "snake's": 132,
#  'dead': 133,
#  'skin': 134,
#  'left': 135,
#  'driveway': 136,
#  'Mustang': 137,
#  'Cobra': 138,
#  'pissing': 139,
#  'puddle': 140,
#  'droplets': 141,
#  'sandal': 142,
#  'indian': 143,
#  'summer': 144,
#  "neighbor's": 145,
#  'daughter': 146,
#  'sunbathes': 147,
#  'beside': 148,
#  'their': 149,
#  'empty': 150,
#  'pool': 151,
#  'chill': 152,
#  'new': 153,
#  'blossoms': 154,
#  'glow': 155,
#  'spring': 156,
#  'scattering': 157,
#  'flowers': 158,
#  'magnolia': 159,
#  'nineteen': 160,
#  'years': 161,
#  'bowing': 162,
#  "one's": 163,
#  'passing': 164,
#  'under': 165,
#  'lilac': 166,
#  'heavy': 167,
#  'snow': 168,
#  'note': 169,
#  'takes': 170,
#  'Winter': 171,
#  'maple': 172,
#  'and': 173,
#  'fresh': 174,
#  'breeze': 175,
#  'or': 176,
#  'advance': 177,
#  'age': 178,
#  'forgotten': 179,
#  'tea': 180,
#  'sudden': 181,
#  'gust': 182,
#  'carp': 183,
#  'leap': 184,
#  'poles': 185,
#  'gulp': 186,
#  'air': 187,
#  'sand': 188,
#  'through': 189,
#  'fingers': 190,
#  'tracery': 191,
#  'palms': 192,
#  'midnight': 193,
#  'blue': 194,
#  'silken': 195,
#  'winds': 196,
#  'i': 197,
#  'wrapped': 198,
#  'quietness': 199,
#  'cottonwood': 200,
#  'seeds': 201,
#  'march': 202,
#  'scent': 203,
#  'lilacs': 204,
#  'pressed': 205,
#  'book': 206,
#  'insomnia': 207,
#  'goose': 208,
#  'lost': 209,
#  'alep': 210,
#  'bombings': 211,
#  'bathroom': 212,
#  'window': 213,
#  'misted': 214,
#  'afterthebell': 215,
#  'just': 216,
#  'umbrellas': 217,
#  'ashes': 218,
#  'evening': 219,
#  'this': 220,
#  'man': 221,
#  'reflection': 222,
#  'is': 223,
#  'it': 224,
#  'asleep': 225,
#  'golden': 226,
#  'dot': 227,
#  'ear': 228,
#  'forty': 229,
#  'one': 230,
#  'backtoschool': 231,
#  'still': 232,
#  'bit': 233,
#  'high': 234,
#  'tide': 235,
#  'near': 236,
#  'dunes': 237,
#  'friday': 238,
#  'silence': 239,
#  'office': 240,
#  'keyboard': 241,
#  'wife': 242,
#  'home': 243,
#  'hospital': 244,
#  'hibiscus': 245,
#  'bloom': 246,
#  'dark': 247,
#  'warmth': 248,
#  'hand': 249,
#  'mine': 250,
#  'mixed': 251,
#  'angry': 252,
#  'words': 253,
#  'tears': 254,
#  'behind': 255,
#  'open': 256,
#  'doorway': 257,
#  'nothing': 258,
#  'but': 259,
#  'darkness': 260,
#  'backyardBBQ': 261,
#  'rope': 262,
#  'A': 263,
#  'pink': 264,
#  'tulips': 265,
#  'mist': 266,
#  'Harvest': 267,
#  'dancing': 268,
#  'husband': 269,
#  'living': 270,
#  'way': 271,
#  'grass': 272,
#  'parts': 273,
#  'as': 274,
#  'pheasant': 275,
#  'passes': 276,
#  "spring's": 277,
#  'confusion': 278,
#  'voice': 279,
#  'all': 280,
#  'over': 281,
#  'again': 282,
#  'giantmoon': 283,
#  'bark': 284,
#  'echos': 285,
#  'fence': 286,
#  'November': 287,
#  'finds': 288,
#  'birds': 289,
#  'hedge': 290,
#  'garden': 291,
#  'embrace': 292,
#  'smell': 293,
#  'sun': 294,
#  'dried': 295,
#  'laundry': 296,
#  'montana': 297,
#  'horses': 298,
#  'backs': 299,
#  'blowing': 300,
#  'Sackofcheeries': 301,
#  'clouds': 302,
#  'grow': 303,
#  'road': 304,
#  'coast': 305,
#  "farmer's": 306,
#  'market': 307,
#  'paints': 308,
#  'flower': 309,
#  "child's": 310,
#  'cheek': 311,
#  'misty': 312,
#  'echoes': 313,
#  'jay': 314,
#  'cries': 315,
#  'pines': 316,
#  'alabastermoon': 317,
#  'glowing': 318,
#  'among': 319,
#  'bare': 320,
#  'pine': 321,
#  'tops': 322,
#  'cool': 323,
#  'mountain': 324,
#  'scramble': 325,
#  'house': 326,
#  'sparrows': 327,
#  'conference': 328,
#  'call': 329,
#  'sisters': 330,
#  'neighbor’s': 331,
#  'clematis': 332,
#  'side': 333,
#  'free': 334,
#  'love': 335,
#  'soup': 336,
#  'turned': 337,
#  'toward': 338,
#  'deep': 339,
#  'wrinkles': 340,
#  'an': 341,
#  'elder': 342,
#  'becoming': 343,
#  'dusk': 344,
#  'harsh': 345,
#  'pull': 346,
#  'our': 347,
#  'chairs': 348,
#  'into': 349,
#  'can': 350,
#  'see': 351,
#  'shaky': 352,
#  'handwriting': 353,
#  'vacant': 354,
#  'lot': 355,
#  'overgrown': 356,
#  'queen': 357,
#  'anne’s': 358,
#  'lace': 359,
#  'car': 360,
#  'top': 361,
#  'glories': 362,
#  'climbing': 363,
#  'day': 364,
#  'settles': 365,
#  'down': 366,
#  'world': 367,
#  'dust': 368,
#  'zazen': 369,
#  'bevel': 370,
#  'mirror': 371,
#  'throws': 372,
#  'rainbow': 373,
#  'another': 374,
#  'year': 375,
#  'those': 376,
#  'crossed': 377,
#  'names': 378,
#  'address': 379,
#  'constellation': 380,
#  'trucks': 381,
#  'jump': 382,
#  'neon': 383,
#  'puddles': 384,
#  'breathe': 385,
#  'rosemary': 386,
#  'alone': 387,
#  'fork': 388,
#  'pasta': 389,
#  'bowl': 390,
#  'trains': 391,
#  'approaching': 392,
#  'someone': 393,
#  'platform': 394,
#  'are': 395,
#  'mountains': 396,
#  'hedgehog': 397,
#  'deepens': 398,
#  'Crotonhedges': 399,
#  'faux': 400,
#  'fall': 401,
#  'foliage': 402,
#  'South': 403,
#  'Florida': 404,
#  'blood': 405,
#  'barbed': 406,
#  'wire': 407,
#  'pale': 408,
#  'reveals': 409,
#  'crime': 410,
#  'tang': 411,
#  'salt': 412,
#  'spray': 413,
#  'pier': 414,
#  'late': 415,
#  'coolness': 416,
#  'verandah': 417,
#  'hereyes': 418,
#  'reflect': 419,
#  'singing': 420,
#  'dawn': 421,
#  'Before': 422,
#  'By': 423,
#  'small': 424,
#  'The': 425,
#  'crickets': 426,
#  "ElHueso'sdrybones": 427,
#  'uniform': 428,
#  'that': 429,
#  'he': 430,
#  'so': 431,
#  'disgraced': 432,
#  "childhood's": 433,
#  'gift': 434,
#  'first': 435,
#  'dandelion': 436,
#  "dog's": 437,
#  'sharp': 438,
#  'gunfire': 439,
#  'butterfly': 440,
#  'wings': 441,
#  'loud': 442,
#  'flapping': 443,
#  "temple's": 444,
#  'Ordinarymorning': 445,
#  'bluest': 446,
#  'skies': 447,
#  'crisp': 448,
#  'clear': 449,
#  'until': 450,
#  'shadows': 451,
#  'reflects': 452,
#  'know': 453,
#  'well': 454,
#  "dad's": 455,
#  'Cracked': 456,
#  'statue': 457,
#  'Buddha': 458,
#  'reminder': 459,
#  'everything': 460,
#  'turn': 461,
#  'off': 462,
#  'pumpkin': 463,
#  'predawn': 464,
#  'harvest': 465,
#  'wildflower': 466,
#  'bouquet': 467,
#  'country': 468,
#  'highway': 469,
#  'endless': 470,
#  'carefully': 471,
#  'saved': 472,
#  'used': 473,
#  'hidden': 474,
#  'poverty': 475,
#  'hike': 476,
#  'honey': 477,
#  'covers': 478,
#  'old': 479,
#  'distantthunder': 480,
#  'boy': 481,
#  'sets': 482,
#  'coin': 483,
#  'rail': 484,
#  'track': 485,
#  'braille': 486,
#  'box': 487,
#  'sleeping': 488,
#  'pills': 489,
#  'tracks': 490,
#  'thoughts': 491,
#  'yellow': 492,
#  'ball': 493,
#  'yarn': 494,
#  'mother’s': 495,
#  'short': 496,
#  'packed': 497,
#  'urn': 498,
#  'lingering': 499,
#  'rare': 500,
#  'books': 501,
#  'faint': 502,
#  'pencil': 503,
#  'marks': 504,
#  'wall': 505,
#  'church': 506,
#  'graveyard': 507,
#  'cloud': 508,
#  'crows': 509,
#  'hover': 510,
#  'stone': 511,
#  'angels': 512,
#  'therapy': 513,
#  'session': 514,
#  'by': 515,
#  'fireflies': 516,
#  'escape': 517,
#  'glass': 518,
#  'jar': 519,
#  'starry': 520,
#  'rice': 521,
#  'song': 522,
#  'sang': 523,
#  "summer's": 524,
#  'footprints': 525,
#  'little': 526,
#  'deeper': 527,
#  'offshoring': 528,
#  'jobs': 529,
#  'horizon': 530,
#  'work': 531,
#  'heels': 532,
#  'hang': 533,
#  'steps': 534,
#  'two': 535,
#  'moons': 536,
#  'somewhere': 537,
#  'ports': 538,
#  'him': 539,
#  "it's": 540,
#  'too': 541,
#  'hot': 542,
#  'shop': 543,
#  'wasps': 544,
#  'drinking': 545,
#  'town': 546,
#  'fountain': 547,
#  'parting': 548,
#  'kiss': 549,
#  'mixture': 550,
#  'sweet': 551,
#  'peppers': 552,
#  'buttercup': 553,
#  'three': 554,
#  'coke': 555,
#  'kitchen': 556,
#  'table': 557,
#  "boy's": 558,
#  'bedroom': 559,
#  "blackbird's": 560,
#  'nest': 561,
#  'found': 562,
#  'almostChristmas': 563,
#  'thinking': 564,
#  'how': 565,
#  'best': 566,
#  'reveal': 567,
#  'dad': 568,
#  'beats': 569,
#  'mum': 570,
#  'cry': 571,
#  'magpie': 572,
#  "bonfire's": 573,
#  'niece': 574,
#  'cups': 575,
#  'hands': 576,
#  'around': 577,
#  'firefly': 578,
#  'police': 579,
#  'watch': 580,
#  'crowds': 581,
#  "children's": 582,
#  'carnival': 583,
#  "horse's": 584,
#  'teeth': 585,
#  'drowned': 586,
#  'familiar': 587,
#  'sounds': 588,
#  'net': 589,
#  'curtains': 590,
#  'glides': 591,
#  'leaving': 592,
#  'snowball': 593,
#  'cairn': 594,
#  'pensioners': 595,
#  'walk': 596,
#  'slow': 597,
#  'drip': 598,
#  'thatch': 599,
#  'wolf': 600,
#  'howl': 601,
#  'lingers': 602,
#  'fades': 603,
#  "night's": 604,
#  'eerie': 605,
#  'invasive': 606,
#  'species': 607,
#  'barber': 608,
#  'points': 609,
#  'hairs': 610,
#  'sprout': 611,
#  'yard': 612,
#  'lakeside': 613,
#  'makes': 614,
#  "loon's": 615,
#  'much': 616,
#  'more': 617,
#  'haunting': 618,
#  'river': 619,
#  'stops': 620,
#  'buy': 621,
#  'worms': 622,
#  'steady': 623,
#  'rants': 624,
#  'boss': 625,
#  'supper': 626,
#  'storm': 627,
#  'sends': 628,
#  'kids': 629,
#  'neighbors': 630,
#  'sign': 631,
#  'shovels': 632,
#  'become': 633,
#  'halfpriced': 634,
#  'sale': 635,
#  'items': 636,
#  'days': 637,
#  'dentist': 638,
#  'explains': 639,
#  'payment': 640,
#  'plans': 641,
#  'mailbox': 642,
#  'loses': 643,
#  'snowplow': 644,
#  'desert': 645,
#  'rear': 646,
#  'view': 647,
#  'flashing': 648,
#  'young': 649,
#  'lake': 650,
#  'ice': 651,
#  'sings': 652,
#  'tune': 653,
#  'ancient': 654,
#  'chapter': 655,
#  'six': 656,
#  'snap': 657,
#  'quilts': 658,
#  'cleaners': 659,
#  'false': 660,
#  'hope': 661,
#  'film': 662,
#  'oil': 663,
#  'carries': 664,
#  'bent': 665,
#  'rainbows': 666,
#  'downstream': 667,
#  'midwinter': 668,
#  'thaw': 669,
#  'icicle': 670,
#  'drips': 671,
#  'its': 672,
#  'own': 673,
#  'pace': 674,
#  'august': 675,
#  'dock': 676,
#  'seagulls': 677,
#  'stand': 678,
#  'legs': 679,
#  'strong': 680,
#  'back': 681,
#  'forth': 682,
#  'streetlight': 683,
#  'reflections': 684,
#  'sultry': 685,
#  'afternoon': 686,
#  'only': 687,
#  'crosses': 688,
#  'dirt': 689,
#  'April': 690,
#  'Iowa': 691,
#  'hogs': 692,
#  'Minnesota': 693,
#  'sake': 694,
#  'bottom': 695,
#  'cup': 696,
#  'latesummer': 697,
#  'copper': 698,
#  'wishes': 699,
#  'collect': 700,
#  'darkening': 701,
#  'strikes': 702,
#  'cockscomb’s': 703,
#  'worn': 704,
#  'places': 705,
#  'wood': 706,
#  'buddha': 707,
#  'newhighway': 708,
#  'every': 709,
#  'mile': 710,
#  'corpse': 711,
#  'buzzard': 712,
#  'bouquets': 713,
#  'speaker': 714,
#  "senior's": 715,
#  'celebrate': 716,
#  '700': 717,
#  'pm': 718,
#  'roadside': 719,
#  'rest': 720,
#  'stop': 721,
#  'adds': 722,
#  'haiku': 723,
#  'graffiti': 724,
#  'snowy': 725,
#  'footbridge': 726,
#  'water': 727,
#  'famous': 728,
#  'divorce': 729,
#  'cactus': 730,
#  'crumbs': 731,
#  'have': 732,
#  'maternity': 733,
#  'ward': 734,
#  'hard': 735,
#  'looks': 736,
#  'when': 737,
#  'shake': 738,
#  'gumball': 739,
#  'machine': 740,
#  'dripping': 741,
#  'headstone': 742,
#  'inscription': 743,
#  'ship’s': 744,
#  'crew': 745,
#  'sea': 746,
#  'vigil': 747,
#  'kerosene': 748,
#  'lamp': 749,
#  'growing': 750,
#  'dim': 751,
#  'wild': 752,
#  'violet': 753,
#  'sunny': 754,
#  'hill': 755,
#  'noon': 756,
#  'time': 757,
#  'nap': 758,
#  'sheperds': 759,
#  'eyes': 760,
#  'flock': 761,
#  'many': 762,
#  'campfires': 763,
#  'hunting': 764,
#  'shirt': 765,
#  'hillside': 766,
#  'thunder': 767,
#  'barely': 768,
#  'plume': 769,
#  'smoke': 770,
#  'leather': 771,
#  'saddle': 772,
#  'cherry': 773,
#  'colored': 774,
#  'shiny': 775,
#  'smells': 776,
#  'horse': 777,
#  'same': 778,
#  'shines': 779,
#  'us': 780,
#  'both': 781,
#  'these': 782,
#  'sheets': 783,
#  'ferocious': 784,
#  'storms': 785,
#  'wakened': 786,
#  'wet': 787,
#  'tongue': 788,
#  'wicked': 789,
#  'news': 790,
#  'Sunday': 791,
#  'wine': 792,
#  'piled': 793,
#  'trunk': 794,
#  'weight': 795,
#  'muddy': 796,
#  'jerrycan': 797,
#  'rinse': 798,
#  'scurry': 799,
#  'silent': 800,
#  'flight': 801,
#  'raptor': 802,
#  'your': 803,
#  'breath': 804,
#  'neck': 805,
#  'churchyard': 806,
#  'where': 807,
#  'father': 808,
#  'god': 809,
#  'bruised': 810,
#  'apples': 811,
#  'coffee': 812,
#  'spoonful': 813,
#  'sugar': 814,
#  'stirred': 815,
#  'whitelight': 816,
#  'shore': 817,
#  'even': 818,
#  'heron': 819,
#  'has': 820,
#  'flown': 821,
#  'moving': 822,
#  'growth': 823,
#  'inches': 824,
#  'wallpaper': 825,
#  'hush': 826,
#  'bubbling': 827,
#  "grandpa's": 828,
#  'potbellied': 829,
#  'stove': 830,
#  'shifting': 831,
#  'grey': 832,
#  'December': 833,
#  'beans': 834,
#  'cinnamon': 835,
#  'toast': 836,
#  'piercing': 837,
#  'wail': 838,
#  'express': 839,
#  'monsoon': 840,
#  'beyond': 841,
#  'rush': 842,
#  'lavender': 843,
#  'blooms': 844,
#  'violets': 845,
#  'pot': 846,
#  'train': 847,
#  'oh': 848,
#  'frost': 849,
#  'mug': 850,
#  'against': 851,
#  'insistent': 852,
#  'bell': 853,
#  'cream': 854,
#  'vendor': 855,
#  'sits': 856,
#  'petals': 857,
#  'flying': 858,
#  'higher': 859,
#  'valley': 860,
#  'redpoppydolls': 861,
#  'sit': 862,
#  'beach': 863,
#  'children': 864,
#  'Tohoku': 865,
#  'centipede': 866,
#  'aah': 867,
#  "summer'send": 868,
#  'tin': 869,
#  'roof': 870,
#  'temple': 871,
#  'amongst': 872,
#  'cedar': 873,
#  'trees': 874,
#  'forgetting': 875,
#  'step': 876,
#  'egret': 877,
#  'stands': 878,
#  'field': 879,
#  'creeps': 880,
#  'drift': 881,
#  'August': 882,
#  'sky': 883,
#  'child': 884,
#  'dreams': 885,
#  'crowd': 886,
#  'emptiness': 887,
#  "beggar's": 888,
#  'smallwhitebutterflies': 889,
#  'starts': 890,
#  'think': 891,
#  'might': 892,
#  'be': 893,
#  'fortieth': 894,
#  'birthday': 895,
#  'fastening': 896,
#  'belt': 897,
#  'hole': 898,
#  'thunderstorm': 899,
#  'filling': 900,
#  'tension': 901,
#  'thighs': 902,
#  'no': 903,
#  'real': 904,
#  'reason': 905,
#  'sadness': 906,
#  'platform9': 907,
#  'shapes': 908,
#  'swooping': 909,
#  'gulls': 910,
#  'beam': 911,
#  'christmaslights': 912,
#  'above': 913,
#  'skein': 914,
#  'twilight': 915,
#  'geese': 916,
#  'Oh': 917,
#  'fills': 918,
#  'circles': 919,
#  'Moss': 920,
#  'tiles': 921,
#  'First': 922,
#  'then': 923,
#  'overcast': 924,
#  'moth': 925,
#  'lands': 926,
#  'screen': 927,
#  'hanging': 928,
#  'shade': 929,
#  'does': 930,
#  'novembersun': 931,
#  'leaning': 932,
#  'tree': 933,
#  'CochraneAlberta': 934,
#  'Coyotes': 935,
#  'howling': 936,
#  'Honking': 937,
#  'I5': 938,
#  'corridor': 939,
#  'Microsofties': 940,
#  'creep': 941,
#  'slowly': 942,
#  'nice': 943,
#  'cars': 944,
#  "rain's": 945,
#  'phrase': 946,
#  'pane': 947,
#  'strand': 948,
#  'flailing': 949,
#  'low': 950,
#  'star': 951,
#  'gray': 952,
#  'shiver': 953,
#  'daffodils': 954,
#  'bones': 955,
#  'watching': 956,
#  'drum': 957,
#  'beat': 958,
#  'deaf': 959,
#  'scribblings': 960,
#  'prayer': 961,
#  'giant': 962,
#  'wave': 963,
#  'burning': 964,
#  'nth': 965,
#  'unanswered': 966,
#  'leavescrackling': 967,
#  'grave': 968,
#  'tiny': 969,
#  'sweep': 970,
#  'leavings': 971,
#  'seeps': 972,
#  'mulch': 973,
#  'bed': 974,
#  'berry': 975,
#  'falls': 976,
#  'Staining': 977,
#  'fridge': 978,
#  'onto': 979,
#  'floor': 980,
#  'daisy': 981,
#  'bedraggled': 982,
#  'upright': 983,
#  'wooden': 984,
#  'cracked': 985,
#  'display': 986,
#  'buyers': 987,
#  'here': 988,
#  'there': 989,
#  'breaking': 990,
#  "dusk's": 991,
#  'bright': 992,
#  'pass': 993,
#  'rebuild': 994,
#  'fit': 995,
#  'flat': 996,
#  'tire': 997,
#  'peach': 998,
#  'voices': 999,
#  ...}

# %% [markdown]
# Now that we have turned characters into tokens with corresponding indexes we can vectorise our training examples by one-hot-encoding them and subsequently creating 3D numpy arrays for X and Y:
#
# `X`: This is an (n_haikus, max_len, vocab_size) dimensional array.
# - We have max_len timesteps for each training example
# - At each time step the input is one of vocab_size possible values and is represented as a one-hot vector. e.g. X[i,t,:] is a one-hot vector representing the value of the i-th example at time t.
#
# `Y`: a (max_len, n_haikus, vocab_size) dimensional array
#
# We're using the previous values to predict the next value. Therefore each traing example Y is just training example X moved one step ahead.

# %%
max_len = max_len - 1

# %%
X = np.zeros((n_haikus, max_len, vocab_size), dtype = 'float32')
Y = np.zeros((max_len, n_haikus, vocab_size), dtype = 'float32')

# %%
#vectorise haikus - turn them into a list of char/word indexes
haiku_vectors = []
for i, haiku in enumerate(haikus):
    haiku_vec = []
    for j in range(len(haiku)):
        haiku_vec.append(token_index.get(haiku[j]))
    haiku_vectors.append(haiku_vec)

# %%
X_vec = []
Y_vec = []
for i, vec in enumerate(haiku_vectors):
    X_vec.append(vec[:-1])
    Y_vec.append(vec[1:])

# %%
for i, vec in enumerate(X_vec):
    for j, idx in enumerate(vec):
        X[i, j, idx] = 1
        
for i, vec in enumerate(Y_vec):
    for j, idx in enumerate(vec):
        Y[j, i, idx] = 1

# %% [markdown]
# # 2. Building an LSTM model

# %%
#number of dimensions for hidden state (a) of each LSTM cell
n_a = 800

# %% [markdown]
# We implement LSTM forward pass defined by the following:
#
# Forget gate:
#
# $$\mathbf{\Gamma}_f^{\langle t \rangle} = \sigma(\mathbf{W}_f[\mathbf{a}^{\langle t-1 \rangle}, \mathbf{x}^{\langle t \rangle}] + \mathbf{b}_f)\tag{1} $$
#
# Candidate value:
#
# $$\mathbf{\tilde{c}}^{\langle t \rangle} = \tanh\left( \mathbf{W}_{c} [\mathbf{a}^{\langle t - 1 \rangle}, \mathbf{x}^{\langle t \rangle}] + \mathbf{b}_{c} \right) \tag{3}$$
#
# Update gate:
#
# $$\mathbf{\Gamma}_i^{\langle t \rangle} = \sigma(\mathbf{W}_i[a^{\langle t-1 \rangle}, \mathbf{x}^{\langle t \rangle}] + \mathbf{b}_i)\tag{2} $$
#
# Cell state:
# $$ \mathbf{c}^{\langle t \rangle} = \mathbf{\Gamma}_f^{\langle t \rangle}* \mathbf{c}^{\langle t-1 \rangle} + \mathbf{\Gamma}_{i}^{\langle t \rangle} *\mathbf{\tilde{c}}^{\langle t \rangle} \tag{4} $$
#
# Output gate:
# $$ \mathbf{\Gamma}_o^{\langle t \rangle}=  \sigma(\mathbf{W}_o[\mathbf{a}^{\langle t-1 \rangle}, \mathbf{x}^{\langle t \rangle}] + \mathbf{b}_{o})\tag{5}$$
#
# Hidden state:
# $$ \mathbf{a}^{\langle t \rangle} = \mathbf{\Gamma}_o^{\langle t \rangle} * \tanh(\mathbf{c}^{\langle t \rangle})\tag{6} $$
#
# Prediction:
# $$\mathbf{y}^{\langle t \rangle}_{pred} = \textrm{softmax}(\mathbf{W}_{y} \mathbf{a}^{\langle t \rangle} + \mathbf{b}_{y})$$
#
# We want to generate new characters at test time predicting the next character based on the last character and the parameters (which can pass information about previous characters too) so we need to build LSTM architecture which implements such inference. So we use keras functional API to build a custom model.
#
# We build a model by stacking keras layers on top of one another:
# 1. Input layer (specifying shape of input)
# - tensorflow.keras.layers.Input() class
# 2.
#
#
# LSTM_cell:
#
# Takes hidden state as input and returns the next hidden state
#
# dense_layer:
#
# Dense implements the operation: output = activation(dot(input, kernel) + bias) where:
# - activation = element-wise activation function passed as the activation argument
# - kernel = weights matrix created by the layer
# - bias = bias vector created by the layer
#
# Thus here we use Dense to calculated y_pred = softmax(dot(Wya, a) + by)

# %%
#define the layer objects of the model globally so that they are fixed when used in a model function

LSTM_cell = LSTM(n_a, return_state = True) #shape of output is n_a, and of weight n_a x input[0]

prediction_layer = Dense(vocab_size, activation='softmax')

reshape_layer = Reshape((1, vocab_size))

# %%
def LSTM_model(max_len, n_a, vocab_size):
    
    #specify the shape of input X
    X = Input(shape=(max_len, vocab_size))
    
    #specify the size of accepted a0 and c) inputs
    a0 = Input(shape=(n_a,), name='a0')
    c0 = Input(shape=(n_a,), name='c0')
    
    #initiliase cell state and hidden state
    a = a0
    c = c0
    
    #create an empty list to append predictions (outputs of Dense)
    outputs = []
    
    for t in range(max_len):
        
        #adds a layer for the next input (i.e. next character and next timestep)
        #lambda allows to specify the operation to be applied as a function on a tensor in a layer
        #here it just takes a slice of x for a given timestep and returns it
        x_t = Lambda(lambda x_t: X[:,t,:])(X) #each takes a slice of X as input so this is a slicing layer
        
        # reshapes x to be (1, vocab_size) 
        x_t = reshape_layer(x_t) #reshapes the slice
        
        #one step of LSTM to update hidden state and cell state
        a, _, c = LSTM_cell(x_t, initial_state=[c, a])
        
        #apply softmax to a function of hidden state to get prediction
        output = prediction_layer(a)
        
        outputs.append(output)
        
    model = Model(inputs= [X,a0,c0], outputs= outputs)
    
    return model

# %%
#def our model
model = LSTM_model(max_len = max_len , n_a = n_a, vocab_size = vocab_size)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 12, 15889)]  0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 15889)        0           input_1[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 15889)     0           lambda[0][0]
#                                                                  lambda_1[0][0]
#                                                                  lambda_2[0][0]
#                                                                  lambda_3[0][0]
#                                                                  lambda_4[0][0]
#                                                                  lambda_5[0][0]
#                                                                  lambda_6[0][0]
#                                                                  lambda_7[0][0]
#                                                                  lambda_8[0][0]
#                                                                  lambda_9[0][0]
#                                                                  lambda_10[0][0]
#                                                                  lambda_11[0][0]
# __________________________________________________________________________________________________
# c0 (InputLayer)                 [(None, 800)]        0
# __________________________________________________________________________________________________
# a0 (InputLayer)                 [(None, 800)]        0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 15889)        0           input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 800), (None, 53408000    reshape[0][0]
#                                                                  c0[0][0]
#                                                                  a0[0][0]
#                                                                  reshape[1][0]
#                                                                  lstm[0][2]
#                                                                  lstm[0][0]
#                                                                  reshape[2][0]
#                                                                  lstm[1][2]
#                                                                  lstm[1][0]
#                                                                  reshape[3][0]
#                                                                  lstm[2][2]
#                                                                  lstm[2][0]
#                                                                  reshape[4][0]
#                                                                  lstm[3][2]
#                                                                  lstm[3][0]
#                                                                  reshape[5][0]
#                                                                  lstm[4][2]
#                                                                  lstm[4][0]
#                                                                  reshape[6][0]
#                                                                  lstm[5][2]
#                                                                  lstm[5][0]
#                                                                  reshape[7][0]
#                                                                  lstm[6][2]
#                                                                  lstm[6][0]
#                                                                  reshape[8][0]
#                                                                  lstm[7][2]
#                                                                  lstm[7][0]
#                                                                  reshape[9][0]
#                                                                  lstm[8][2]
#                                                                  lstm[8][0]
#                                                                  reshape[10][0]
#                                                                  lstm[9][2]
#                                                                  lstm[9][0]
#                                                                  reshape[11][0]
#                                                                  lstm[10][2]
#                                                                  lstm[10][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 15889)        0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 15889)        0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 15889)        0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 15889)        0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 15889)        0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 15889)        0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 15889)        0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 15889)        0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 15889)        0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 15889)        0           input_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 15889)        12727089    lstm[0][0]
#                                                                  lstm[1][0]
#                                                                  lstm[2][0]
#                                                                  lstm[3][0]
#                                                                  lstm[4][0]
#                                                                  lstm[5][0]
#                                                                  lstm[6][0]
#                                                                  lstm[7][0]
#                                                                  lstm[8][0]
#                                                                  lstm[9][0]
#                                                                  lstm[10][0]
#                                                                  lstm[11][0]
# ==================================================================================================
# Total params: 66,135,089
# Trainable params: 66,135,089
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(model, "my_first_model_with_shape_info.png", show_shapes=True)

#should be seversl outputs and several lstm layers

# %%
#compile the model

optimizer = Adam(lr=0.01, beta_1=0.9, beta_2=0.9999, decay=0.001)

model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
k = n_haikus
a0 = np.zeros((k, n_a))
c0 = np.zeros((k, n_a))

# %%
history = model.fit([X, a0, c0], list(Y), epochs=50)
# Out:
# Train on 8394 samples
# Epoch 1/50
# 8394/8394 [==============================] - 555s 66ms/sample - loss: 92.7064 - dense_loss: 8.5468 - dense_1_loss: 6.4073 - dense_2_loss: 5.6712 - dense_3_loss: 7.8269 - dense_4_loss: 9.8553 - dense_5_loss: 9.9637 - dense_6_loss: 8.2307 - dense_7_loss: 5.9448 - dense_8_loss: 6.8126 - dense_9_loss: 9.4134 - dense_10_loss: 12.3933 - dense_11_loss: 1.5964 - dense_accuracy: 0.0299 - dense_1_accuracy: 0.2953 - dense_2_accuracy: 0.3873 - dense_3_accuracy: 0.2231 - dense_4_accuracy: 0.0117 - dense_5_accuracy: 0.0329 - dense_6_accuracy: 0.2224 - dense_7_accuracy: 0.4055 - dense_8_accuracy: 0.2654 - dense_9_accuracy: 0.0319 - dense_10_accuracy: 0.0000e+00 - dense_11_accuracy: 0.9621
# Epoch 2/50
# 8394/8394 [==============================] - 545s 65ms/sample - loss: 73.2495 - dense_loss: 6.7201 - dense_1_loss: 4.9616 - dense_2_loss: 4.5815 - dense_3_loss: 6.1788 - dense_4_loss: 7.8080 - dense_5_loss: 7.9081 - dense_6_loss: 6.6048 - dense_7_loss: 4.7691 - dense_8_loss: 5.4847 - dense_9_loss: 7.5063 - dense_10_loss: 9.6760 - dense_11_loss: 1.0486 - dense_accuracy: 0.0851 - dense_1_accuracy: 0.3165 - dense_2_accuracy: 0.4034 - dense_3_accuracy: 0.2331 - dense_4_accuracy: 0.0166 - dense_5_accuracy: 0.0353 - dense_6_accuracy: 0.2302 - dense_7_accuracy: 0.4254 - dense_8_accuracy: 0.2771 - dense_9_accuracy: 0.0360 - dense_10_accuracy: 0.0000e+00 - dense_11_accuracy: 0.9989

# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-29-6c2e79b90101> in <module>
#       1 path = os.getcwd()+'/LSTMmodel'
# ----> 2 model.save(path)
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in save(self, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#    2000     # pylint: enable=line-too-long
#    2001     save.save_model(self, filepath, overwrite, include_optimizer, save_format,
# -> 2002                     signatures, options, save_traces)
#    2003
#    2004   def save_weights(self,
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/keras/saving/save.py in save_model(model, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#     155   else:
#     156     saved_model_save.save(model, filepath, overwrite, include_optimizer,
# --> 157                           signatures, options, save_traces)
#     158
#     159
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/keras/saving/saved_model/save.py in save(model, filepath, overwrite, include_optimizer, signatures, options, save_traces)
#      87     with distribution_strategy_context._get_default_replica_context():  # pylint: disable=protected-access
#      88       with utils.keras_option_scope(save_traces):
# ---> 89         save_lib.save(model, filepath, signatures, options)
#      90
#      91   if not include_optimizer:
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/saved_model/save.py in save(obj, export_dir, signatures, options)
#    1031
#    1032   _, exported_graph, object_saver, asset_info = _build_meta_graph(
# -> 1033       obj, signatures, options, meta_graph_def)
#    1034   saved_model.saved_model_schema_version = constants.SAVED_MODEL_SCHEMA_VERSION
#    1035
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/saved_model/save.py in _build_meta_graph(obj, signatures, options, meta_graph_def)
#    1196
#    1197   with save_context.save_context(options):
# -> 1198     return _build_meta_graph_impl(obj, signatures, options, meta_graph_def)
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/saved_model/save.py in _build_meta_graph_impl(obj, signatures, options, meta_graph_def)
#    1151   asset_info, exported_graph = _fill_meta_graph_def(meta_graph_def,
#    1152                                                     saveable_view, signatures,
# -> 1153                                                     options.namespace_whitelist)
#    1154   if options.function_aliases:
#    1155     function_aliases = meta_graph_def.meta_info_def.function_aliases
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/saved_model/save.py in _fill_meta_graph_def(meta_graph_def, saveable_view, signature_functions, namespace_whitelist)
#     685
#     686   with exported_graph.as_default():
# --> 687     signatures = _generate_signatures(signature_functions, resource_map)
#     688     for concrete_function in saveable_view.concrete_functions:
#     689       concrete_function.add_to_graph()
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/saved_model/save.py in _generate_signatures(signature_functions, resource_map)
#     551                                                   signature_key, function.name))
#     552     outputs = _call_function_with_mapped_captures(
# --> 553         function, mapped_inputs, resource_map)
#     554     signatures[signature_key] = signature_def_utils.build_signature_def(
#     555         _tensor_dict_to_tensorinfo(exterior_argument_placeholders),
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/saved_model/save.py in _call_function_with_mapped_captures(function, args, resource_map)
#     503   """Calls `function` in the exported graph, using mapped resource captures."""
#     504   export_captures = _map_captures_to_created_tensors(function.graph.captures,
# --> 505                                                      resource_map)
#     506   # Calls the function quite directly, since we have new captured resource
#     507   # tensors we need to feed in which weren't part of the original function
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/saved_model/save.py in _map_captures_to_created_tensors(original_captures, resource_map)
#     426            "(from gc.get_referrers, limited to two hops):\n{}"
#     427           ).format(interior,
# --> 428                    "\n".join([repr(obj) for obj in trackable_referrers])))
#     429     export_captures.append(mapped_resource)
#     430   return export_captures
#
# AssertionError: Tried to export a function which references untracked resource Tensor("input_1_1:0", shape=(None, 12, 15889), dtype=float32).TensorFlow objects (e.g. tf.Variable) captured by functions must be tracked by assigning them to an attribute of a tracked object or assigned to an attribute of the main object directly.
#
# Trackable Python objects referring to this tensor (from gc.get_referrers, limited to two hops):

# %% [markdown]
# ## Sampling with temperature

# %%
def sample_vec(prob_vec, temperature):
    #prob_vec = np.array(prob_vec).as_type('float64')
    prob_vec = tf.math.divide(tf.math.log(prob_vec),temperature)
    exp_prob_vec = tf.math.exp(prob_vec)
    p = tf.math.divide(exp_prob_vec, tf.math.reduce_sum(exp_prob_vec)) #normalize
    
    dist = tfp.distributions.Multinomial(total_count = 1, probs = p) #draw samples from multinomial dsitribution with p = prob, of given output
    sample = dist.sample()
    print(sample.shape)
    print(sample)
    
    y = K.argmax(sample)
    y = tf.one_hot(indices=y, depth= vocab_size)
    y = RepeatVector(1)(y) 
    print(y.shape)
    return y

# %%
temperature = 3

# %%
def generate_sequence(LSTM_cell, prediction_layer, n_values = vocab_size, n_a = n_a, length = max_len, temperature = temperature):
    
    x0 = Input(shape=(1, n_values))
    
    a0 = Input(shape=(n_a,), name='a0')
    c0 = Input(shape=(n_a,), name='c0')
    
    a = a0
    c = c0
    x = x0
    
    outputs = []
    
    for t in range(length):
        x = reshape_layer(x)
        a, _, c = LSTM_cell(x, initial_state=[a, c]) #or [c,a]
        pred = prediction_layer(a)
        y = Lambda(lambda a: sample_vec(a,temperature))(pred)
        outputs.append(y)
        x = y

    
    inference_model = tf.keras.Model(inputs=[x0,a0,c0], outputs=outputs)
    return inference_model

# %%
inference_model = generate_sequence(LSTM_cell, prediction_layer, n_values = vocab_size, n_a = n_a, length = max_len, temperature = temperature)
# Out:
# (None, 15889)
# Tensor("lambda_192/lambda_192_Multinomial/sample/Reshape:0", shape=(None, 15889), dtype=float32)
# (None, 1, 15889)
# (None, 15889)
# Tensor("lambda_193/lambda_193_Multinomial/sample/Reshape:0", shape=(None, 15889), dtype=float32)
# (None, 1, 15889)
# (None, 15889)
# Tensor("lambda_194/lambda_194_Multinomial/sample/Reshape:0", shape=(None, 15889), dtype=float32)
# (None, 1, 15889)
# (None, 15889)
# Tensor("lambda_195/lambda_195_Multinomial/sample/Reshape:0", shape=(None, 15889), dtype=float32)
# (None, 1, 15889)
# (None, 15889)
# Tensor("lambda_196/lambda_196_Multinomial/sample/Reshape:0", shape=(None, 15889), dtype=float32)
# (None, 1, 15889)
# (None, 15889)
# Tensor("lambda_197/lambda_197_Multinomial/sample/Reshape:0", shape=(None, 15889), dtype=float32)
# (None, 1, 15889)
# (None, 15889)
# Tensor("lambda_198/lambda_198_Multinomial/sample/Reshape:0", shape=(None, 15889), dtype=float32)
# (None, 1, 15889)
# (None, 15889)
# Tensor("lambda_199/lambda_199_Multinomial/sample/Reshape:0", shape=(None, 15889), dtype=float32)
# (None, 1, 15889)
# (None, 15889)
# Tensor("lambda_200/lambda_200_Multinomial/sample/Reshape:0", shape=(None, 15889), dtype=float32)
# (None, 1, 15889)
# (None, 15889)
# Tensor("lambda_201/lambda_201_Multinomial/sample/Reshape:0", shape=(None, 15889), dtype=float32)
# (None, 1, 15889)
# (None, 15889)
# Tensor("lambda_202/lambda_202_Multinomial/sample/Reshape:0", shape=(None, 15889), dtype=float32)
# (None, 1, 15889)
# (None, 15889)
# Tensor("lambda_203/lambda_203_Multinomial/sample/Reshape:0", shape=(None, 15889), dtype=float32)
# (None, 1, 15889)

# %% [markdown]
# ## Prediction

# %%
x_init = np.zeros((1, 1, vocab_size))
a_init = np.zeros((1, n_a))
c_init = np.zeros((1, n_a))

# %%
x_init.shape
# Out:
# (1, 1, 15889)

# %%
def predict_sequence(inference_model = inference_model, x_nit = x_init, a_init = a_init, c_init = c_init):
    predictions = inference_model.predict([x_init, a_init, c_init])
    indices = np.argmax(predictions, axis=-1)
    results = []
    for i in range(max_len):
        results.append(indices[i,0,0])
    
    return results

# %%
index_token = {}
for key, value in token_index.items():
    index_token[value] = key

# %%
#find a way to parametrize with temperature!

def get_haiku():
    pred = predict_sequence(inference_model = inference_model, x_nit = x_init, a_init = a_init, c_init = c_init)
    sequence = []
    for elem in pred:
        sequence.append(index_token[elem])
    for elem in sequence:
        print(elem)

# %%
get_haiku()
# Out:
# MOVE
# meme
# /
# getting
# woman
# on
# her
# shuttered
# the
# majority
# this
# /

# %%
get_haiku()
# Out:
# Spectre
# sometimes
# everyone
# I'm
# night
# /
# family
# evening
# /
# I'm
# morning
# up
