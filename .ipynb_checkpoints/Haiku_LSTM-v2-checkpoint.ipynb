# %% [markdown]
# # Haiku generator with LSTM

# %% [markdown]
# Haiku dataset https://www.kaggle.com/hjhalani30/haiku-dataset

# %% [markdown]
# # 1. Data preparation and cleaning

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.3.1'

# %%
import matplotlib.pyplot as plt 
import numpy as np 
import os 
import pandas as pd 
import sys
import keras
from keras.models import load_model, Model
from keras.layers import Dense, Activation, Dropout, Input, LSTM, Reshape, Lambda, RepeatVector
from keras.initializers import glorot_uniform
from keras.utils import to_categorical, plot_model
from keras.optimizers import Adam
from keras import backend as K
import tensorflow as tf
tf.compat.v1.disable_eager_execution()

# %%
dirname = os.getcwd()
filename = "all_haiku.csv"
path_to_dataset = os.path.join(dirname, filename)
n_examples = 124295
data = pd.read_csv(path_to_dataset, delimiter=',', nrows = n_examples)
nRow, nCol = data.shape
print(f'There are {nRow} rows and {nCol} columns')

#cols 1-3 are 1st, 2nd, and 3rd lines of the haiku respectively
# Out:
# There are 124295 rows and 6 columns

# %%
data = data.to_numpy()

# %%
#cols 1-3 are 1st, 2nd, and 3rd lines of the haiku respectively

X_1_0 = data[:,1]
X_2_0 = data[:,2]
X_3_0 = data[:,3]

# %%
X_1 = []
X_2 = []
X_3 = []
for i in range(n_examples):
    if type(X_1_0[i]) == str and type(X_2_0[i]) == str and type(X_3_0[i]) == str:
        X_1.append(X_1_0[i])
        X_2.append(X_2_0[i])
        X_3.append(X_3_0[i])

# %%
#clean the data to get rid off "-" etc
#to make it sensitive to lines, maybe we could implement a line break as some symbol e.g. "|" and merge the X's together
punctuation = ['-', '--', '~', '—', '.', ';', ',', ':', '?', '!', '#', '(', ')', '<', '>', '*', '%', '{', '_', ']', '[', '@', '`', '\xa0', '=', '"', '&', '–', '…', '“', '”']

end_of_line = '.'
end_of_haiku = '/'

for i in range(len(X_1)):
    for p in punctuation:
        if p in X_1[i]:
            X_1[i] = X_1[i].replace(p, '')
        if p in X_2[i]:
            X_2[i] = X_2[i].replace(p, '')
        if p in X_3[i]:
            X_3[i] = X_3[i].replace(p, '')
   
    #delete redundant spaces
    if X_1[i][-3:-1] == '   ':
        X_1[i] = X_1[i].replace('   ', '')
    elif X_1[i][-2:-1] == '  ':
        X_1[i] = X_1[i].replace('  ', '')   
    elif X_1[i][-1] == ' ':
        X_1[i] = X_1[i].replace(' ', '')
    
    if X_2[i][-3:-1] == '   ':
        X_2[i] = X_2[i].replace('   ', '')
    elif X_2[i][-2:-1] == '  ':
        X_2[i] = X_2[i].replace('  ', '')   
    elif X_1[i][-1] == ' ':
        X_2[i] = X_2[i].replace(' ', '')
        
    if X_3[i][-3:-1] == '   ':
        X_3[i] = X_1[i].replace('   ', '')
    elif X_3[i][-2:-1] == '  ':
        X_3[i] = X_1[i].replace('  ', '')   
    elif X_3[i][-1] == ' ':
        X_1[i] = X_1[i].replace(' ', '')
    

    
    #X_1[i] += end_of_line
    #X_2[i] += end_of_line
    #X_3[i] += end_of_line
    #X_3[i] += end_of_haiku

# %%
haiku_vec = []
for i in range(len(X_1)):
    haiku = X_1[i].split()
    haiku.append('/')
    for word in X_2[i].split():
        haiku.append(word)
    haiku.append('/')
    for word in X_3[i].split():
        haiku.append(word)
    haiku.append('/')
    haiku_vec.append(haiku)

# %%
haikus = haiku_vec

# %%
short_haikus = []
for i in range(len(haikus)):
    if len(haikus[i]) == 13:
        short_haikus.append(haikus[i])
n_haikus = len(short_haikus)
print(n_haikus)

haikus = short_haikus
# Out:
# 8394

# %%
max_len = 0
for i in range(n_haikus):
    max_len = max(max_len, len(haikus[i]))
    
print(max_len)
# Out:
# 13

# %%
#create words dict

token_index = {}
idx = -1
for haiku in haikus:
    for i in range(len(haiku)):
        if haiku[i] not in token_index:
            token_index[haiku[i]] = idx+1
            idx += 1

# %%
vocab_size = len(token_index)
print(vocab_size)
#our total length is 5x times that
# Out:
# 15889

# %% [markdown]
# Now that we have turned characters into tokens with corresponding indexes we can vectorise our training examples by one-hot-encoding them and subsequently creating 3D numpy arrays for X and Y:
#
# `X`: This is an (n_haikus, max_len, vocab_size) dimensional array.
# - We have max_len timesteps for each training example
# - At each time step the input is one of vocab_size possible values and is represented as a one-hot vector. e.g. X[i,t,:] is a one-hot vector representing the value of the i-th example at time t.
#
# `Y`: a (max_len, n_haikus, vocab_size) dimensional array
#
# We're using the previous values to predict the next value. Therefore each traing example Y is just training example X moved one step ahead.

# %%
max_len = max_len - 1

# %%
X = np.zeros((n_haikus, max_len, vocab_size), dtype = 'float32')
Y = np.zeros((max_len, n_haikus, vocab_size), dtype = 'float32')

# %%
#vectorise haikus - turn them into a list of char/word indexes
haiku_vectors = []
for i, haiku in enumerate(haikus):
    haiku_vec = []
    for j in range(len(haiku)):
        haiku_vec.append(token_index.get(haiku[j]))
    haiku_vectors.append(haiku_vec)

# %%
X_vec = []
Y_vec = []
for i, vec in enumerate(haiku_vectors):
    X_vec.append(vec[:-1])
    Y_vec.append(vec[1:])

# %%
for i, vec in enumerate(X_vec):
    for j, idx in enumerate(vec):
        X[i, j, idx] = 1
        
for i, vec in enumerate(Y_vec):
    for j, idx in enumerate(vec):
        Y[j, i, idx] = 1

# %% [markdown]
# # 2. Building an LSTM model

# %%
#number of dimensions for hidden state (a) of each LSTM cell
n_a = 500

# %% [markdown]
# We implement LSTM forward pass defined by the following:
#
# Forget gate:
#
# $$\mathbf{\Gamma}_f^{\langle t \rangle} = \sigma(\mathbf{W}_f[\mathbf{a}^{\langle t-1 \rangle}, \mathbf{x}^{\langle t \rangle}] + \mathbf{b}_f)\tag{1} $$
#
# Candidate value:
#
# $$\mathbf{\tilde{c}}^{\langle t \rangle} = \tanh\left( \mathbf{W}_{c} [\mathbf{a}^{\langle t - 1 \rangle}, \mathbf{x}^{\langle t \rangle}] + \mathbf{b}_{c} \right) \tag{3}$$
#
# Update gate:
#
# $$\mathbf{\Gamma}_i^{\langle t \rangle} = \sigma(\mathbf{W}_i[a^{\langle t-1 \rangle}, \mathbf{x}^{\langle t \rangle}] + \mathbf{b}_i)\tag{2} $$
#
# Cell state:
# $$ \mathbf{c}^{\langle t \rangle} = \mathbf{\Gamma}_f^{\langle t \rangle}* \mathbf{c}^{\langle t-1 \rangle} + \mathbf{\Gamma}_{i}^{\langle t \rangle} *\mathbf{\tilde{c}}^{\langle t \rangle} \tag{4} $$
#
# Output gate:
# $$ \mathbf{\Gamma}_o^{\langle t \rangle}=  \sigma(\mathbf{W}_o[\mathbf{a}^{\langle t-1 \rangle}, \mathbf{x}^{\langle t \rangle}] + \mathbf{b}_{o})\tag{5}$$
#
# Hidden state:
# $$ \mathbf{a}^{\langle t \rangle} = \mathbf{\Gamma}_o^{\langle t \rangle} * \tanh(\mathbf{c}^{\langle t \rangle})\tag{6} $$
#
# Prediction:
# $$\mathbf{y}^{\langle t \rangle}_{pred} = \textrm{softmax}(\mathbf{W}_{y} \mathbf{a}^{\langle t \rangle} + \mathbf{b}_{y})$$
#
# We want to generate new characters at test time predicting the next character based on the last character and the parameters (which can pass information about previous characters too) so we need to build LSTM architecture which implements such inference. So we use keras functional API to build a custom model.
#
# We build a model by stacking keras layers on top of one another:
# 1. Input layer (specifying shape of input)
# - tensorflow.keras.layers.Input() class
# 2.
#
#
# LSTM_cell:
#
# Takes hidden state as input and returns the next hidden state
#
# dense_layer:
#
# Dense implements the operation: output = activation(dot(input, kernel) + bias) where:
# - activation = element-wise activation function passed as the activation argument
# - kernel = weights matrix created by the layer
# - bias = bias vector created by the layer
#
# Thus here we use Dense to calculated y_pred = softmax(dot(Wya, a) + by)

# %%
#define the layer objects of the model globally so that they are fixed when used in a model function

LSTM_cell = LSTM(n_a, return_state = True) #shape of output is n_a, and of weight n_a x input[0]

prediction_layer = Dense(vocab_size, activation='softmax')

reshape_layer = Reshape((1, vocab_size))

# %%
def LSTM_model(max_len, n_a, vocab_size):
    
    #specify the shape of input X
    X = Input(shape=(max_len, vocab_size))
    
    #specify the size of accepted a0 and c) inputs
    a0 = Input(shape=(n_a,), name='a0')
    c0 = Input(shape=(n_a,), name='c0')
    
    #initiliase cell state and hidden state
    a = a0
    c = c0
    
    #create an empty list to append predictions (outputs of Dense)
    outputs = []
    
    for t in range(max_len):
        
        #adds a layer for the next input (i.e. next character and next timestep)
        #lambda allows to specify the operation to be applied as a function on a tensor in a layer
        #here it just takes a slice of x for a given timestep and returns it
        x_t = Lambda(lambda x_t: X[:,t,:])(X) #each takes a slice of X as input so this is a slicing layer
        
        # reshapes x to be (1, vocab_size) 
        x_t = reshape_layer(x_t) #reshapes the slice
        
        #one step of LSTM to update hidden state and cell state
        a, _, c = LSTM_cell(x_t, initial_state=[c, a])
        
        #apply softmax to a function of hidden state to get prediction
        output = prediction_layer(a)
        
        outputs.append(output)
        
    model = Model(inputs= [X,a0,c0], outputs= outputs)
    
    return model

# %%
#def our model
model = LSTM_model(max_len = max_len , n_a = n_a, vocab_size = vocab_size)

# %%
model.summary()
# Out:
# Model: "functional_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 12, 15889)]  0
# __________________________________________________________________________________________________
# lambda_108 (Lambda)             (None, 15889)        0           input_5[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 15889)     0           lambda_108[0][0]
#                                                                  lambda_109[0][0]
#                                                                  lambda_110[0][0]
#                                                                  lambda_111[0][0]
#                                                                  lambda_112[0][0]
#                                                                  lambda_113[0][0]
#                                                                  lambda_114[0][0]
#                                                                  lambda_115[0][0]
#                                                                  lambda_116[0][0]
#                                                                  lambda_117[0][0]
#                                                                  lambda_118[0][0]
#                                                                  lambda_119[0][0]
# __________________________________________________________________________________________________
# c0 (InputLayer)                 [(None, 500)]        0
# __________________________________________________________________________________________________
# a0 (InputLayer)                 [(None, 500)]        0
# __________________________________________________________________________________________________
# lambda_109 (Lambda)             (None, 15889)        0           input_5[0][0]
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   [(None, 500), (None, 32780000    reshape_4[0][0]
#                                                                  c0[0][0]
#                                                                  a0[0][0]
#                                                                  reshape_4[1][0]
#                                                                  lstm_4[0][2]
#                                                                  lstm_4[0][0]
#                                                                  reshape_4[2][0]
#                                                                  lstm_4[1][2]
#                                                                  lstm_4[1][0]
#                                                                  reshape_4[3][0]
#                                                                  lstm_4[2][2]
#                                                                  lstm_4[2][0]
#                                                                  reshape_4[4][0]
#                                                                  lstm_4[3][2]
#                                                                  lstm_4[3][0]
#                                                                  reshape_4[5][0]
#                                                                  lstm_4[4][2]
#                                                                  lstm_4[4][0]
#                                                                  reshape_4[6][0]
#                                                                  lstm_4[5][2]
#                                                                  lstm_4[5][0]
#                                                                  reshape_4[7][0]
#                                                                  lstm_4[6][2]
#                                                                  lstm_4[6][0]
#                                                                  reshape_4[8][0]
#                                                                  lstm_4[7][2]
#                                                                  lstm_4[7][0]
#                                                                  reshape_4[9][0]
#                                                                  lstm_4[8][2]
#                                                                  lstm_4[8][0]
#                                                                  reshape_4[10][0]
#                                                                  lstm_4[9][2]
#                                                                  lstm_4[9][0]
#                                                                  reshape_4[11][0]
#                                                                  lstm_4[10][2]
#                                                                  lstm_4[10][0]
# __________________________________________________________________________________________________
# lambda_110 (Lambda)             (None, 15889)        0           input_5[0][0]
# __________________________________________________________________________________________________
# lambda_111 (Lambda)             (None, 15889)        0           input_5[0][0]
# __________________________________________________________________________________________________
# lambda_112 (Lambda)             (None, 15889)        0           input_5[0][0]
# __________________________________________________________________________________________________
# lambda_113 (Lambda)             (None, 15889)        0           input_5[0][0]
# __________________________________________________________________________________________________
# lambda_114 (Lambda)             (None, 15889)        0           input_5[0][0]
# __________________________________________________________________________________________________
# lambda_115 (Lambda)             (None, 15889)        0           input_5[0][0]
# __________________________________________________________________________________________________
# lambda_116 (Lambda)             (None, 15889)        0           input_5[0][0]
# __________________________________________________________________________________________________
# lambda_117 (Lambda)             (None, 15889)        0           input_5[0][0]
# __________________________________________________________________________________________________
# lambda_118 (Lambda)             (None, 15889)        0           input_5[0][0]
# __________________________________________________________________________________________________
# lambda_119 (Lambda)             (None, 15889)        0           input_5[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 15889)        7960389     lstm_4[0][0]
#                                                                  lstm_4[1][0]
#                                                                  lstm_4[2][0]
#                                                                  lstm_4[3][0]
#                                                                  lstm_4[4][0]
#                                                                  lstm_4[5][0]
#                                                                  lstm_4[6][0]
#                                                                  lstm_4[7][0]
#                                                                  lstm_4[8][0]
#                                                                  lstm_4[9][0]
#                                                                  lstm_4[10][0]
#                                                                  lstm_4[11][0]
# ==================================================================================================
# Total params: 40,740,389
# Trainable params: 40,740,389
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(model, "my_first_model_with_shape_info.png", show_shapes=True)

#should be seversl outputs and several lstm layers

# %%
#compile the model

optimizer = Adam(lr=0.01, beta_1=0.9, beta_2=0.9999, decay=0.001)
#optimizer = 'rmsprop'

model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
- dense_4_8_accuracy: 0.9981 - dense_4_9_accuracy: 0.9994 - dense_4_10_accuracy: 0.9989 - dense_4_11_accuracy: 1.0000
# Epoch 48/50
# 8394/8394 [==============================] - 262s 31ms/sample - loss: 2.5444 - dense_4_loss: 1.8163 - dense_4_1_loss: 0.2812 - dense_4_2_loss: 0.1435 - dense_4_3_loss: 0.0847 - dense_4_4_loss: 0.0452 - dense_4_5_loss: 0.0283 - dense_4_6_loss: 0.0273 - dense_4_7_loss: 0.0382 - dense_4_8_loss: 0.0432 - dense_4_9_loss: 0.0196 - dense_4_10_loss: 0.0125 - dense_4_11_loss: 3.7341e-05 - dense_4_accuracy: 0.4355 - dense_4_1_accuracy: 0.8721 - dense_4_2_accuracy: 0.9450 - dense_4_3_accuracy: 0.9755 - dense_4_4_accuracy: 0.9912 - dense_4_5_accuracy: 0.9962 - dense_4_6_accuracy: 0.9965 - dense_4_7_accuracy: 0.9977 - dense_4_8_accuracy: 0.9981 - dense_4_9_accuracy: 0.9993 - dense_4_10_accuracy: 0.9988 - dense_4_11_accuracy: 1.0000
# Epoch 49/50
# 8394/8394 [==============================] - 261s 31ms/sample - loss: 2.5249 - dense_4_loss: 1.8068 - dense_4_1_loss: 0.2806 - dense_4_2_loss: 0.1419 - dense_4_3_loss: 0.0821 - dense_4_4_loss: 0.0439 - dense_4_5_loss: 0.0261 - dense_4_6_loss: 0.0264 - dense_4_7_loss: 0.0370 - dense_4_8_loss: 0.0426 - dense_4_9_loss: 0.0184 - dense_4_10_loss: 0.0113 - dense_4_11_loss: 4.3191e-05 - dense_4_accuracy: 0.4330 - dense_4_1_accuracy: 0.8729 - dense_4_2_accuracy: 0.9420 - dense_4_3_accuracy: 0.9741 - dense_4_4_accuracy: 0.9911 - dense_4_5_accuracy: 0.9963 - dense_4_6_accuracy: 0.9967 - dense_4_7_accuracy: 0.9979 - dense_4_8_accuracy: 0.9981 - dense_4_9_accuracy: 0.9993 - dense_4_10_accuracy: 0.9989 - dense_4_11_accuracy: 1.0000
# Epoch 50/50
# 8394/8394 [==============================] - 617s 73ms/sample - loss: 2.5084 - dense_4_loss: 1.8076 - dense_4_1_loss: 0.2805 - dense_4_2_loss: 0.1407 - dense_4_3_loss: 0.0785 - dense_4_4_loss: 0.0423 - dense_4_5_loss: 0.0244 - dense_4_6_loss: 0.0254 - dense_4_7_loss: 0.0359 - dense_4_8_loss: 0.0409 - dense_4_9_loss: 0.0168 - dense_4_10_loss: 0.0102 - dense_4_11_loss: 3.7183e-05 - dense_4_accuracy: 0.4285 - dense_4_1_accuracy: 0.8762 - dense_4_2_accuracy: 0.9422 - dense_4_3_accuracy: 0.9755 - dense_4_4_accuracy: 0.9907 - dense_4_5_accuracy: 0.9963 - dense_4_6_accuracy: 0.9967 - dense_4_7_accuracy: 0.9980 - dense_4_8_accuracy: 0.9981 - dense_4_9_accuracy: 0.9992 - dense_4_10_accuracy: 0.9988 - dense_4_11_accuracy: 1.0000

# %%
def sample_vec(prob_vec, temperature = 1):
    #prob_vec = np.array(prob_vec).as_type('float64')
    prob_vec = tf.math.divide(tf.math.log(prob_vec),temperature)
    exp_prob_vec = tf.math.exp(prob_vec)
    p = tf.math.divide(exp_prob_vec, tf.math.reduce_sum(exp_prob_vec)) #normalize
    
    #how in tensorflow?
    probs = tfp.distributions.Multinomial(total_count = 1, probs = p) #draw samples from multinomial dsitribution with p = prob, of given output
    y = K.argmax(probs)
    y = tf.one_hot(indices=y, depth= vocab_size)
    y = RepeatVector(1)(y) 
    return y

# %%
def one_hot(x):
    x = K.argmax(x)
    x = tf.one_hot(indices=x, depth=78) 
    x = RepeatVector(1)(x)
    return x

# %%
def inference_model(LSTM_cell, prediction_layer, vocab_size = vocab_size, n_a = n_a, length = max_len, temperature = 1):
    """
    Generate new sequences of values (words) with the trained model layers.
    
    Arguments:
    LSTM_cell - trained LSTM cell
    prediction_layer - trained prediction_layer returning y_pred for each timestep
    vocab_size - size of of our vocabulary corresponding to the number of unique values that are one-hot-encoded
    n_a - number of units of hidden state in the LSTM cell
    length - length of generated sequence
    
    Returns:
    inference_model - Keras model
    """
    
    # First word 
    x0 = Input(shape=(1, vocab_size))
    
    #def hidden state and cell state
    a0 = Input(shape=(n_a,), name='a0')
    c0 = Input(shape=(n_a,), name='c0')
    a = a0
    c = c0
    x = x0
    
    outputs = []
    
    # Loop over length and each time generate a word
    for t in range(length):
        
        a, _, c = LSTM_cell(x, initial_state=[a, c])
        
        y = prediction_layer(a)

        outputs.append(y)
        
        x = y #update x to be one hot rep of last output y
        x = reshape_layer(x)
        
    model = Model(inputs= [x0,a0,c0], outputs=outputs)
    
    
    return model

# %%
inference_model = inference_model(LSTM_cell, prediction_layer, vocab_size = vocab_size, n_a = n_a, length = vocab_size, temperature = 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-305-e7e696ccd5f2> in <module>
# ----> 1 inference_model = inference_model(LSTM_cell, prediction_layer, vocab_size = vocab_size, n_a = n_a, length = vocab_size, temperature = 1)
#
# <ipython-input-304-d6fc83eea9b3> in inference_model(LSTM_cell, prediction_layer, vocab_size, n_a, length, temperature)
#      29     for t in range(length):
#      30
# ---> 31         a, _, c = LSTM_cell(x, initial_state=[a, c])
#      32
#      33         y = prediction_layer(a)
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/keras/layers/recurrent.py in __call__(self, inputs, initial_state, constants, **kwargs)
#     703             nest.map_structure(lambda _: None, inputs)) + additional_specs
#     704       # Perform the call with temporarily replaced input_spec
# --> 705       self.input_spec = full_input_spec
#     706       output = super(RNN, self).__call__(full_input, **kwargs)
#     707       # Remove the additional_specs from input spec and keep the rest. It is
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/keras/engine/base_layer_v1.py in __call__(self, *args, **kwargs)
#     750     if build_graph and base_layer_utils.needs_keras_history(inputs):
#     751       base_layer_utils.create_keras_history(inputs)
# --> 752
#     753     with call_context.enter(self, inputs, build_graph, training_value):
#     754       # Check input assumptions set after layer building, e.g. input shape.
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/keras/engine/input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     156     return tensor_shape.TensorShape(shape)
#     157
# --> 158
#     159 def assert_input_compatibility(input_spec, inputs, layer_name):
#     160   """Checks compatibility between the layer and provided inputs.
#
# ValueError: Layer lstm_4 expects 13 inputs, but it received 3 input tensors. Inputs received: [<tf.Tensor 'input_18:0' shape=(None, 1, 15889) dtype=float32>, <tf.Tensor 'a0_17:0' shape=(None, 500) dtype=float32>, <tf.Tensor 'c0_17:0' shape=(None, 500) dtype=float32>]
