# %% [markdown]
# # Haiku generator with LSTM

# %% [markdown]
# Haiku dataset https://www.kaggle.com/hjhalani30/haiku-dataset

# %% [markdown]
# # 1. Data preparation and cleaning

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.4.0'

# %%
import matplotlib.pyplot as plt 
import numpy as np 
import os 
import pandas as pd 
import sys
import keras
from keras.models import load_model, Model
from keras.layers import Dense, Activation, Dropout, Input, LSTM, Reshape, Lambda, RepeatVector
from keras.initializers import glorot_uniform
from keras.utils import to_categorical, plot_model
from keras.optimizers import Adam
from keras import backend as K
import tensorflow as tf
import tensorflow_probability as tfp
tf.compat.v1.disable_eager_execution()

# %%
dirname = os.getcwd()
filename = "all_haiku.csv"
path_to_dataset = os.path.join(dirname, filename)
n_examples = 124295
data = pd.read_csv(path_to_dataset, delimiter=',', nrows = n_examples)
nRow, nCol = data.shape
print(f'There are {nRow} rows and {nCol} columns')

#cols 1-3 are 1st, 2nd, and 3rd lines of the haiku respectively
# Out:
# There are 124295 rows and 6 columns

# %%
data = data.to_numpy()

# %%
#cols 1-3 are 1st, 2nd, and 3rd lines of the haiku respectively

X_1_0 = data[:,1]
X_2_0 = data[:,2]
X_3_0 = data[:,3]

# %%
X_1 = []
X_2 = []
X_3 = []
for i in range(n_examples):
    if type(X_1_0[i]) == str and type(X_2_0[i]) == str and type(X_3_0[i]) == str:
        X_1.append(X_1_0[i])
        X_2.append(X_2_0[i])
        X_3.append(X_3_0[i])

# %%
#clean the data to get rid off "-" etc
#to make it sensitive to lines, maybe we could implement a line break as some symbol e.g. "|" and merge the X's together
punctuation = ['-', '--', '~', '—', '.', ';', ',', ':', '?', '!', '#', '(', ')', '<', '>', '*', '%', '{', '_', ']', '[', '@', '`', '\xa0', '=', '"', '&', '–', '…', '“', '”']

end_of_line = '.'
end_of_haiku = '/'

for i in range(len(X_1)):
    for p in punctuation:
        if p in X_1[i]:
            X_1[i] = X_1[i].replace(p, '')
        if p in X_2[i]:
            X_2[i] = X_2[i].replace(p, '')
        if p in X_3[i]:
            X_3[i] = X_3[i].replace(p, '')
   
    #delete redundant spaces
    if X_1[i][-3:-1] == '   ':
        X_1[i] = X_1[i].replace('   ', '')
    elif X_1[i][-2:-1] == '  ':
        X_1[i] = X_1[i].replace('  ', '')   
    elif X_1[i][-1] == ' ':
        X_1[i] = X_1[i].replace(' ', '')
    
    if X_2[i][-3:-1] == '   ':
        X_2[i] = X_2[i].replace('   ', '')
    elif X_2[i][-2:-1] == '  ':
        X_2[i] = X_2[i].replace('  ', '')   
    elif X_1[i][-1] == ' ':
        X_2[i] = X_2[i].replace(' ', '')
        
    if X_3[i][-3:-1] == '   ':
        X_3[i] = X_1[i].replace('   ', '')
    elif X_3[i][-2:-1] == '  ':
        X_3[i] = X_1[i].replace('  ', '')   
    elif X_3[i][-1] == ' ':
        X_1[i] = X_1[i].replace(' ', '')
    

    
    #X_1[i] += end_of_line
    #X_2[i] += end_of_line
    #X_3[i] += end_of_line
    #X_3[i] += end_of_haiku

# %%
haiku_vec = []
for i in range(len(X_1)):
    haiku = X_1[i].split()
    haiku.append('/')
    for word in X_2[i].split():
        haiku.append(word)
    haiku.append('/')
    for word in X_3[i].split():
        haiku.append(word)
    haiku.append('/')
    haiku_vec.append(haiku)

# %%
haikus = haiku_vec

# %%
short_haikus = []
for i in range(len(haikus)):
    if len(haikus[i]) == 13:
        short_haikus.append(haikus[i])
n_haikus = len(short_haikus)
print(n_haikus)

haikus = short_haikus
# Out:
# 8394

# %%
max_len = 0
for i in range(n_haikus):
    max_len = max(max_len, len(haikus[i]))
    
print(max_len)
# Out:
# 13

# %%
#create words dict

token_index = {}
idx = -1
for haiku in haikus:
    for i in range(len(haiku)):
        if haiku[i] not in token_index:
            token_index[haiku[i]] = idx+1
            idx += 1

# %%
vocab_size = len(token_index)
print(vocab_size)
#our total length is 5x times that
# Out:
# 15889

# %%
token_index
# Out:
# {'fly': 0,
#  'fishing': 1,
#  '/': 2,
#  'the': 3,
#  'sound': 4,
#  'of': 5,
#  'wind': 6,
#  'in': 7,
#  'reel': 8,
#  'visiting': 9,
#  'graves': 10,
#  'stronger': 11,
#  'October': 12,
#  'at': 13,
#  'my': 14,
#  "grandparents'": 15,
#  'early': 16,
#  'morning': 17,
#  'dew': 18,
#  'squeezing': 19,
#  'last': 20,
#  'drop': 21,
#  'from': 22,
#  'teabag': 23,
#  'winter': 24,
#  'roses': 25,
#  'I': 26,
#  'am': 27,
#  'tired': 28,
#  'reading': 29,
#  'between': 30,
#  'lines': 31,
#  'night': 32,
#  'shift': 33,
#  'a': 34,
#  'quick': 35,
#  'break': 36,
#  'to': 37,
#  'look': 38,
#  'stars': 39,
#  'freeze': 40,
#  'warning': 41,
#  'light': 42,
#  'arc': 43,
#  'welder': 44,
#  'brightens': 45,
#  'need': 46,
#  'pee': 47,
#  'once': 48,
#  'we': 49,
#  'hit': 50,
#  'traffic': 51,
#  'out': 52,
#  'fog': 53,
#  'white': 54,
#  'barn': 55,
#  'with': 56,
#  'painted': 57,
#  'butterflies': 58,
#  'distanthurricane': 59,
#  'middle': 60,
#  'rain': 61,
#  'phone': 62,
#  'rings': 63,
#  'waiting': 64,
#  'for': 65,
#  'bus': 66,
#  'street': 67,
#  'dog': 68,
#  'sniffs': 69,
#  'shadow': 70,
#  'windowpane': 71,
#  'end': 72,
#  'finger': 73,
#  'cold': 74,
#  'moon': 75,
#  'taxi': 76,
#  'driver': 77,
#  'tells': 78,
#  'me': 79,
#  'about': 80,
#  'his': 81,
#  'life': 82,
#  'autumn': 83,
#  'looking': 84,
#  'her': 85,
#  'childhood': 86,
#  'photos': 87,
#  'girlfriend': 88,
#  'older': 89,
#  'than': 90,
#  'next': 91,
#  'room': 92,
#  'sick': 93,
#  'mother': 94,
#  'buswindow': 95,
#  'she': 96,
#  'travels': 97,
#  'full': 98,
#  'on': 99,
#  'head': 100,
#  'dogs': 101,
#  'barking': 102,
#  'perhaps': 103,
#  'was': 104,
#  'cat': 105,
#  'other': 106,
#  'line': 107,
#  'red': 108,
#  'lights': 109,
#  'becomes': 110,
#  'sunset': 111,
#  'each': 112,
#  'sip': 113,
#  'bottle': 114,
#  'moonlight': 115,
#  'face': 116,
#  'long': 117,
#  'before': 118,
#  'came': 119,
#  'after': 120,
#  'leave': 121,
#  'blossoming': 122,
#  'pear': 123,
#  'Pearl': 124,
#  'Harbor': 125,
#  'Day': 126,
#  'Koi': 127,
#  'pond': 128,
#  'littered': 129,
#  'fallen': 130,
#  'leaves': 131,
#  "snake's": 132,
#  'dead': 133,
#  'skin': 134,
#  'left': 135,
#  'driveway': 136,
#  'Mustang': 137,
#  'Cobra': 138,
#  'pissing': 139,
#  'puddle': 140,
#  'droplets': 141,
#  'sandal': 142,
#  'indian': 143,
#  'summer': 144,
#  "neighbor's": 145,
#  'daughter': 146,
#  'sunbathes': 147,
#  'beside': 148,
#  'their': 149,
#  'empty': 150,
#  'pool': 151,
#  'chill': 152,
#  'new': 153,
#  'blossoms': 154,
#  'glow': 155,
#  'spring': 156,
#  'scattering': 157,
#  'flowers': 158,
#  'magnolia': 159,
#  'nineteen': 160,
#  'years': 161,
#  'bowing': 162,
#  "one's": 163,
#  'passing': 164,
#  'under': 165,
#  'lilac': 166,
#  'heavy': 167,
#  'snow': 168,
#  'note': 169,
#  'takes': 170,
#  'Winter': 171,
#  'maple': 172,
#  'and': 173,
#  'fresh': 174,
#  'breeze': 175,
#  'or': 176,
#  'advance': 177,
#  'age': 178,
#  'forgotten': 179,
#  'tea': 180,
#  'sudden': 181,
#  'gust': 182,
#  'carp': 183,
#  'leap': 184,
#  'poles': 185,
#  'gulp': 186,
#  'air': 187,
#  'sand': 188,
#  'through': 189,
#  'fingers': 190,
#  'tracery': 191,
#  'palms': 192,
#  'midnight': 193,
#  'blue': 194,
#  'silken': 195,
#  'winds': 196,
#  'i': 197,
#  'wrapped': 198,
#  'quietness': 199,
#  'cottonwood': 200,
#  'seeds': 201,
#  'march': 202,
#  'scent': 203,
#  'lilacs': 204,
#  'pressed': 205,
#  'book': 206,
#  'insomnia': 207,
#  'goose': 208,
#  'lost': 209,
#  'alep': 210,
#  'bombings': 211,
#  'bathroom': 212,
#  'window': 213,
#  'misted': 214,
#  'afterthebell': 215,
#  'just': 216,
#  'umbrellas': 217,
#  'ashes': 218,
#  'evening': 219,
#  'this': 220,
#  'man': 221,
#  'reflection': 222,
#  'is': 223,
#  'it': 224,
#  'asleep': 225,
#  'golden': 226,
#  'dot': 227,
#  'ear': 228,
#  'forty': 229,
#  'one': 230,
#  'backtoschool': 231,
#  'still': 232,
#  'bit': 233,
#  'high': 234,
#  'tide': 235,
#  'near': 236,
#  'dunes': 237,
#  'friday': 238,
#  'silence': 239,
#  'office': 240,
#  'keyboard': 241,
#  'wife': 242,
#  'home': 243,
#  'hospital': 244,
#  'hibiscus': 245,
#  'bloom': 246,
#  'dark': 247,
#  'warmth': 248,
#  'hand': 249,
#  'mine': 250,
#  'mixed': 251,
#  'angry': 252,
#  'words': 253,
#  'tears': 254,
#  'behind': 255,
#  'open': 256,
#  'doorway': 257,
#  'nothing': 258,
#  'but': 259,
#  'darkness': 260,
#  'backyardBBQ': 261,
#  'rope': 262,
#  'A': 263,
#  'pink': 264,
#  'tulips': 265,
#  'mist': 266,
#  'Harvest': 267,
#  'dancing': 268,
#  'husband': 269,
#  'living': 270,
#  'way': 271,
#  'grass': 272,
#  'parts': 273,
#  'as': 274,
#  'pheasant': 275,
#  'passes': 276,
#  "spring's": 277,
#  'confusion': 278,
#  'voice': 279,
#  'all': 280,
#  'over': 281,
#  'again': 282,
#  'giantmoon': 283,
#  'bark': 284,
#  'echos': 285,
#  'fence': 286,
#  'November': 287,
#  'finds': 288,
#  'birds': 289,
#  'hedge': 290,
#  'garden': 291,
#  'embrace': 292,
#  'smell': 293,
#  'sun': 294,
#  'dried': 295,
#  'laundry': 296,
#  'montana': 297,
#  'horses': 298,
#  'backs': 299,
#  'blowing': 300,
#  'Sackofcheeries': 301,
#  'clouds': 302,
#  'grow': 303,
#  'road': 304,
#  'coast': 305,
#  "farmer's": 306,
#  'market': 307,
#  'paints': 308,
#  'flower': 309,
#  "child's": 310,
#  'cheek': 311,
#  'misty': 312,
#  'echoes': 313,
#  'jay': 314,
#  'cries': 315,
#  'pines': 316,
#  'alabastermoon': 317,
#  'glowing': 318,
#  'among': 319,
#  'bare': 320,
#  'pine': 321,
#  'tops': 322,
#  'cool': 323,
#  'mountain': 324,
#  'scramble': 325,
#  'house': 326,
#  'sparrows': 327,
#  'conference': 328,
#  'call': 329,
#  'sisters': 330,
#  'neighbor’s': 331,
#  'clematis': 332,
#  'side': 333,
#  'free': 334,
#  'love': 335,
#  'soup': 336,
#  'turned': 337,
#  'toward': 338,
#  'deep': 339,
#  'wrinkles': 340,
#  'an': 341,
#  'elder': 342,
#  'becoming': 343,
#  'dusk': 344,
#  'harsh': 345,
#  'pull': 346,
#  'our': 347,
#  'chairs': 348,
#  'into': 349,
#  'can': 350,
#  'see': 351,
#  'shaky': 352,
#  'handwriting': 353,
#  'vacant': 354,
#  'lot': 355,
#  'overgrown': 356,
#  'queen': 357,
#  'anne’s': 358,
#  'lace': 359,
#  'car': 360,
#  'top': 361,
#  'glories': 362,
#  'climbing': 363,
#  'day': 364,
#  'settles': 365,
#  'down': 366,
#  'world': 367,
#  'dust': 368,
#  'zazen': 369,
#  'bevel': 370,
#  'mirror': 371,
#  'throws': 372,
#  'rainbow': 373,
#  'another': 374,
#  'year': 375,
#  'those': 376,
#  'crossed': 377,
#  'names': 378,
#  'address': 379,
#  'constellation': 380,
#  'trucks': 381,
#  'jump': 382,
#  'neon': 383,
#  'puddles': 384,
#  'breathe': 385,
#  'rosemary': 386,
#  'alone': 387,
#  'fork': 388,
#  'pasta': 389,
#  'bowl': 390,
#  'trains': 391,
#  'approaching': 392,
#  'someone': 393,
#  'platform': 394,
#  'are': 395,
#  'mountains': 396,
#  'hedgehog': 397,
#  'deepens': 398,
#  'Crotonhedges': 399,
#  'faux': 400,
#  'fall': 401,
#  'foliage': 402,
#  'South': 403,
#  'Florida': 404,
#  'blood': 405,
#  'barbed': 406,
#  'wire': 407,
#  'pale': 408,
#  'reveals': 409,
#  'crime': 410,
#  'tang': 411,
#  'salt': 412,
#  'spray': 413,
#  'pier': 414,
#  'late': 415,
#  'coolness': 416,
#  'verandah': 417,
#  'hereyes': 418,
#  'reflect': 419,
#  'singing': 420,
#  'dawn': 421,
#  'Before': 422,
#  'By': 423,
#  'small': 424,
#  'The': 425,
#  'crickets': 426,
#  "ElHueso'sdrybones": 427,
#  'uniform': 428,
#  'that': 429,
#  'he': 430,
#  'so': 431,
#  'disgraced': 432,
#  "childhood's": 433,
#  'gift': 434,
#  'first': 435,
#  'dandelion': 436,
#  "dog's": 437,
#  'sharp': 438,
#  'gunfire': 439,
#  'butterfly': 440,
#  'wings': 441,
#  'loud': 442,
#  'flapping': 443,
#  "temple's": 444,
#  'Ordinarymorning': 445,
#  'bluest': 446,
#  'skies': 447,
#  'crisp': 448,
#  'clear': 449,
#  'until': 450,
#  'shadows': 451,
#  'reflects': 452,
#  'know': 453,
#  'well': 454,
#  "dad's": 455,
#  'Cracked': 456,
#  'statue': 457,
#  'Buddha': 458,
#  'reminder': 459,
#  'everything': 460,
#  'turn': 461,
#  'off': 462,
#  'pumpkin': 463,
#  'predawn': 464,
#  'harvest': 465,
#  'wildflower': 466,
#  'bouquet': 467,
#  'country': 468,
#  'highway': 469,
#  'endless': 470,
#  'carefully': 471,
#  'saved': 472,
#  'used': 473,
#  'hidden': 474,
#  'poverty': 475,
#  'hike': 476,
#  'honey': 477,
#  'covers': 478,
#  'old': 479,
#  'distantthunder': 480,
#  'boy': 481,
#  'sets': 482,
#  'coin': 483,
#  'rail': 484,
#  'track': 485,
#  'braille': 486,
#  'box': 487,
#  'sleeping': 488,
#  'pills': 489,
#  'tracks': 490,
#  'thoughts': 491,
#  'yellow': 492,
#  'ball': 493,
#  'yarn': 494,
#  'mother’s': 495,
#  'short': 496,
#  'packed': 497,
#  'urn': 498,
#  'lingering': 499,
#  'rare': 500,
#  'books': 501,
#  'faint': 502,
#  'pencil': 503,
#  'marks': 504,
#  'wall': 505,
#  'church': 506,
#  'graveyard': 507,
#  'cloud': 508,
#  'crows': 509,
#  'hover': 510,
#  'stone': 511,
#  'angels': 512,
#  'therapy': 513,
#  'session': 514,
#  'by': 515,
#  'fireflies': 516,
#  'escape': 517,
#  'glass': 518,
#  'jar': 519,
#  'starry': 520,
#  'rice': 521,
#  'song': 522,
#  'sang': 523,
#  "summer's": 524,
#  'footprints': 525,
#  'little': 526,
#  'deeper': 527,
#  'offshoring': 528,
#  'jobs': 529,
#  'horizon': 530,
#  'work': 531,
#  'heels': 532,
#  'hang': 533,
#  'steps': 534,
#  'two': 535,
#  'moons': 536,
#  'somewhere': 537,
#  'ports': 538,
#  'him': 539,
#  "it's": 540,
#  'too': 541,
#  'hot': 542,
#  'shop': 543,
#  'wasps': 544,
#  'drinking': 545,
#  'town': 546,
#  'fountain': 547,
#  'parting': 548,
#  'kiss': 549,
#  'mixture': 550,
#  'sweet': 551,
#  'peppers': 552,
#  'buttercup': 553,
#  'three': 554,
#  'coke': 555,
#  'kitchen': 556,
#  'table': 557,
#  "boy's": 558,
#  'bedroom': 559,
#  "blackbird's": 560,
#  'nest': 561,
#  'found': 562,
#  'almostChristmas': 563,
#  'thinking': 564,
#  'how': 565,
#  'best': 566,
#  'reveal': 567,
#  'dad': 568,
#  'beats': 569,
#  'mum': 570,
#  'cry': 571,
#  'magpie': 572,
#  "bonfire's": 573,
#  'niece': 574,
#  'cups': 575,
#  'hands': 576,
#  'around': 577,
#  'firefly': 578,
#  'police': 579,
#  'watch': 580,
#  'crowds': 581,
#  "children's": 582,
#  'carnival': 583,
#  "horse's": 584,
#  'teeth': 585,
#  'drowned': 586,
#  'familiar': 587,
#  'sounds': 588,
#  'net': 589,
#  'curtains': 590,
#  'glides': 591,
#  'leaving': 592,
#  'snowball': 593,
#  'cairn': 594,
#  'pensioners': 595,
#  'walk': 596,
#  'slow': 597,
#  'drip': 598,
#  'thatch': 599,
#  'wolf': 600,
#  'howl': 601,
#  'lingers': 602,
#  'fades': 603,
#  "night's": 604,
#  'eerie': 605,
#  'invasive': 606,
#  'species': 607,
#  'barber': 608,
#  'points': 609,
#  'hairs': 610,
#  'sprout': 611,
#  'yard': 612,
#  'lakeside': 613,
#  'makes': 614,
#  "loon's": 615,
#  'much': 616,
#  'more': 617,
#  'haunting': 618,
#  'river': 619,
#  'stops': 620,
#  'buy': 621,
#  'worms': 622,
#  'steady': 623,
#  'rants': 624,
#  'boss': 625,
#  'supper': 626,
#  'storm': 627,
#  'sends': 628,
#  'kids': 629,
#  'neighbors': 630,
#  'sign': 631,
#  'shovels': 632,
#  'become': 633,
#  'halfpriced': 634,
#  'sale': 635,
#  'items': 636,
#  'days': 637,
#  'dentist': 638,
#  'explains': 639,
#  'payment': 640,
#  'plans': 641,
#  'mailbox': 642,
#  'loses': 643,
#  'snowplow': 644,
#  'desert': 645,
#  'rear': 646,
#  'view': 647,
#  'flashing': 648,
#  'young': 649,
#  'lake': 650,
#  'ice': 651,
#  'sings': 652,
#  'tune': 653,
#  'ancient': 654,
#  'chapter': 655,
#  'six': 656,
#  'snap': 657,
#  'quilts': 658,
#  'cleaners': 659,
#  'false': 660,
#  'hope': 661,
#  'film': 662,
#  'oil': 663,
#  'carries': 664,
#  'bent': 665,
#  'rainbows': 666,
#  'downstream': 667,
#  'midwinter': 668,
#  'thaw': 669,
#  'icicle': 670,
#  'drips': 671,
#  'its': 672,
#  'own': 673,
#  'pace': 674,
#  'august': 675,
#  'dock': 676,
#  'seagulls': 677,
#  'stand': 678,
#  'legs': 679,
#  'strong': 680,
#  'back': 681,
#  'forth': 682,
#  'streetlight': 683,
#  'reflections': 684,
#  'sultry': 685,
#  'afternoon': 686,
#  'only': 687,
#  'crosses': 688,
#  'dirt': 689,
#  'April': 690,
#  'Iowa': 691,
#  'hogs': 692,
#  'Minnesota': 693,
#  'sake': 694,
#  'bottom': 695,
#  'cup': 696,
#  'latesummer': 697,
#  'copper': 698,
#  'wishes': 699,
#  'collect': 700,
#  'darkening': 701,
#  'strikes': 702,
#  'cockscomb’s': 703,
#  'worn': 704,
#  'places': 705,
#  'wood': 706,
#  'buddha': 707,
#  'newhighway': 708,
#  'every': 709,
#  'mile': 710,
#  'corpse': 711,
#  'buzzard': 712,
#  'bouquets': 713,
#  'speaker': 714,
#  "senior's": 715,
#  'celebrate': 716,
#  '700': 717,
#  'pm': 718,
#  'roadside': 719,
#  'rest': 720,
#  'stop': 721,
#  'adds': 722,
#  'haiku': 723,
#  'graffiti': 724,
#  'snowy': 725,
#  'footbridge': 726,
#  'water': 727,
#  'famous': 728,
#  'divorce': 729,
#  'cactus': 730,
#  'crumbs': 731,
#  'have': 732,
#  'maternity': 733,
#  'ward': 734,
#  'hard': 735,
#  'looks': 736,
#  'when': 737,
#  'shake': 738,
#  'gumball': 739,
#  'machine': 740,
#  'dripping': 741,
#  'headstone': 742,
#  'inscription': 743,
#  'ship’s': 744,
#  'crew': 745,
#  'sea': 746,
#  'vigil': 747,
#  'kerosene': 748,
#  'lamp': 749,
#  'growing': 750,
#  'dim': 751,
#  'wild': 752,
#  'violet': 753,
#  'sunny': 754,
#  'hill': 755,
#  'noon': 756,
#  'time': 757,
#  'nap': 758,
#  'sheperds': 759,
#  'eyes': 760,
#  'flock': 761,
#  'many': 762,
#  'campfires': 763,
#  'hunting': 764,
#  'shirt': 765,
#  'hillside': 766,
#  'thunder': 767,
#  'barely': 768,
#  'plume': 769,
#  'smoke': 770,
#  'leather': 771,
#  'saddle': 772,
#  'cherry': 773,
#  'colored': 774,
#  'shiny': 775,
#  'smells': 776,
#  'horse': 777,
#  'same': 778,
#  'shines': 779,
#  'us': 780,
#  'both': 781,
#  'these': 782,
#  'sheets': 783,
#  'ferocious': 784,
#  'storms': 785,
#  'wakened': 786,
#  'wet': 787,
#  'tongue': 788,
#  'wicked': 789,
#  'news': 790,
#  'Sunday': 791,
#  'wine': 792,
#  'piled': 793,
#  'trunk': 794,
#  'weight': 795,
#  'muddy': 796,
#  'jerrycan': 797,
#  'rinse': 798,
#  'scurry': 799,
#  'silent': 800,
#  'flight': 801,
#  'raptor': 802,
#  'your': 803,
#  'breath': 804,
#  'neck': 805,
#  'churchyard': 806,
#  'where': 807,
#  'father': 808,
#  'god': 809,
#  'bruised': 810,
#  'apples': 811,
#  'coffee': 812,
#  'spoonful': 813,
#  'sugar': 814,
#  'stirred': 815,
#  'whitelight': 816,
#  'shore': 817,
#  'even': 818,
#  'heron': 819,
#  'has': 820,
#  'flown': 821,
#  'moving': 822,
#  'growth': 823,
#  'inches': 824,
#  'wallpaper': 825,
#  'hush': 826,
#  'bubbling': 827,
#  "grandpa's": 828,
#  'potbellied': 829,
#  'stove': 830,
#  'shifting': 831,
#  'grey': 832,
#  'December': 833,
#  'beans': 834,
#  'cinnamon': 835,
#  'toast': 836,
#  'piercing': 837,
#  'wail': 838,
#  'express': 839,
#  'monsoon': 840,
#  'beyond': 841,
#  'rush': 842,
#  'lavender': 843,
#  'blooms': 844,
#  'violets': 845,
#  'pot': 846,
#  'train': 847,
#  'oh': 848,
#  'frost': 849,
#  'mug': 850,
#  'against': 851,
#  'insistent': 852,
#  'bell': 853,
#  'cream': 854,
#  'vendor': 855,
#  'sits': 856,
#  'petals': 857,
#  'flying': 858,
#  'higher': 859,
#  'valley': 860,
#  'redpoppydolls': 861,
#  'sit': 862,
#  'beach': 863,
#  'children': 864,
#  'Tohoku': 865,
#  'centipede': 866,
#  'aah': 867,
#  "summer'send": 868,
#  'tin': 869,
#  'roof': 870,
#  'temple': 871,
#  'amongst': 872,
#  'cedar': 873,
#  'trees': 874,
#  'forgetting': 875,
#  'step': 876,
#  'egret': 877,
#  'stands': 878,
#  'field': 879,
#  'creeps': 880,
#  'drift': 881,
#  'August': 882,
#  'sky': 883,
#  'child': 884,
#  'dreams': 885,
#  'crowd': 886,
#  'emptiness': 887,
#  "beggar's": 888,
#  'smallwhitebutterflies': 889,
#  'starts': 890,
#  'think': 891,
#  'might': 892,
#  'be': 893,
#  'fortieth': 894,
#  'birthday': 895,
#  'fastening': 896,
#  'belt': 897,
#  'hole': 898,
#  'thunderstorm': 899,
#  'filling': 900,
#  'tension': 901,
#  'thighs': 902,
#  'no': 903,
#  'real': 904,
#  'reason': 905,
#  'sadness': 906,
#  'platform9': 907,
#  'shapes': 908,
#  'swooping': 909,
#  'gulls': 910,
#  'beam': 911,
#  'christmaslights': 912,
#  'above': 913,
#  'skein': 914,
#  'twilight': 915,
#  'geese': 916,
#  'Oh': 917,
#  'fills': 918,
#  'circles': 919,
#  'Moss': 920,
#  'tiles': 921,
#  'First': 922,
#  'then': 923,
#  'overcast': 924,
#  'moth': 925,
#  'lands': 926,
#  'screen': 927,
#  'hanging': 928,
#  'shade': 929,
#  'does': 930,
#  'novembersun': 931,
#  'leaning': 932,
#  'tree': 933,
#  'CochraneAlberta': 934,
#  'Coyotes': 935,
#  'howling': 936,
#  'Honking': 937,
#  'I5': 938,
#  'corridor': 939,
#  'Microsofties': 940,
#  'creep': 941,
#  'slowly': 942,
#  'nice': 943,
#  'cars': 944,
#  "rain's": 945,
#  'phrase': 946,
#  'pane': 947,
#  'strand': 948,
#  'flailing': 949,
#  'low': 950,
#  'star': 951,
#  'gray': 952,
#  'shiver': 953,
#  'daffodils': 954,
#  'bones': 955,
#  'watching': 956,
#  'drum': 957,
#  'beat': 958,
#  'deaf': 959,
#  'scribblings': 960,
#  'prayer': 961,
#  'giant': 962,
#  'wave': 963,
#  'burning': 964,
#  'nth': 965,
#  'unanswered': 966,
#  'leavescrackling': 967,
#  'grave': 968,
#  'tiny': 969,
#  'sweep': 970,
#  'leavings': 971,
#  'seeps': 972,
#  'mulch': 973,
#  'bed': 974,
#  'berry': 975,
#  'falls': 976,
#  'Staining': 977,
#  'fridge': 978,
#  'onto': 979,
#  'floor': 980,
#  'daisy': 981,
#  'bedraggled': 982,
#  'upright': 983,
#  'wooden': 984,
#  'cracked': 985,
#  'display': 986,
#  'buyers': 987,
#  'here': 988,
#  'there': 989,
#  'breaking': 990,
#  "dusk's": 991,
#  'bright': 992,
#  'pass': 993,
#  'rebuild': 994,
#  'fit': 995,
#  'flat': 996,
#  'tire': 997,
#  'peach': 998,
#  'voices': 999,
#  ...}

# %% [markdown]
# Now that we have turned characters into tokens with corresponding indexes we can vectorise our training examples by one-hot-encoding them and subsequently creating 3D numpy arrays for X and Y:
#
# `X`: This is an (n_haikus, max_len, vocab_size) dimensional array.
# - We have max_len timesteps for each training example
# - At each time step the input is one of vocab_size possible values and is represented as a one-hot vector. e.g. X[i,t,:] is a one-hot vector representing the value of the i-th example at time t.
#
# `Y`: a (max_len, n_haikus, vocab_size) dimensional array
#
# We're using the previous values to predict the next value. Therefore each traing example Y is just training example X moved one step ahead.

# %%
max_len = max_len - 1

# %%
X = np.zeros((n_haikus, max_len, vocab_size), dtype = 'float32')
Y = np.zeros((max_len, n_haikus, vocab_size), dtype = 'float32')

# %%
#vectorise haikus - turn them into a list of char/word indexes
haiku_vectors = []
for i, haiku in enumerate(haikus):
    haiku_vec = []
    for j in range(len(haiku)):
        haiku_vec.append(token_index.get(haiku[j]))
    haiku_vectors.append(haiku_vec)

# %%
X_vec = []
Y_vec = []
for i, vec in enumerate(haiku_vectors):
    X_vec.append(vec[:-1])
    Y_vec.append(vec[1:])

# %%
for i, vec in enumerate(X_vec):
    for j, idx in enumerate(vec):
        X[i, j, idx] = 1
        
for i, vec in enumerate(Y_vec):
    for j, idx in enumerate(vec):
        Y[j, i, idx] = 1

# %% [markdown]
# # 2. Building an LSTM model

# %%
#number of dimensions for hidden state (a) of each LSTM cell
n_a = 500

# %% [markdown]
# We implement LSTM forward pass defined by the following:
#
# Forget gate:
#
# $$\mathbf{\Gamma}_f^{\langle t \rangle} = \sigma(\mathbf{W}_f[\mathbf{a}^{\langle t-1 \rangle}, \mathbf{x}^{\langle t \rangle}] + \mathbf{b}_f)\tag{1} $$
#
# Candidate value:
#
# $$\mathbf{\tilde{c}}^{\langle t \rangle} = \tanh\left( \mathbf{W}_{c} [\mathbf{a}^{\langle t - 1 \rangle}, \mathbf{x}^{\langle t \rangle}] + \mathbf{b}_{c} \right) \tag{3}$$
#
# Update gate:
#
# $$\mathbf{\Gamma}_i^{\langle t \rangle} = \sigma(\mathbf{W}_i[a^{\langle t-1 \rangle}, \mathbf{x}^{\langle t \rangle}] + \mathbf{b}_i)\tag{2} $$
#
# Cell state:
# $$ \mathbf{c}^{\langle t \rangle} = \mathbf{\Gamma}_f^{\langle t \rangle}* \mathbf{c}^{\langle t-1 \rangle} + \mathbf{\Gamma}_{i}^{\langle t \rangle} *\mathbf{\tilde{c}}^{\langle t \rangle} \tag{4} $$
#
# Output gate:
# $$ \mathbf{\Gamma}_o^{\langle t \rangle}=  \sigma(\mathbf{W}_o[\mathbf{a}^{\langle t-1 \rangle}, \mathbf{x}^{\langle t \rangle}] + \mathbf{b}_{o})\tag{5}$$
#
# Hidden state:
# $$ \mathbf{a}^{\langle t \rangle} = \mathbf{\Gamma}_o^{\langle t \rangle} * \tanh(\mathbf{c}^{\langle t \rangle})\tag{6} $$
#
# Prediction:
# $$\mathbf{y}^{\langle t \rangle}_{pred} = \textrm{softmax}(\mathbf{W}_{y} \mathbf{a}^{\langle t \rangle} + \mathbf{b}_{y})$$
#
# We want to generate new characters at test time predicting the next character based on the last character and the parameters (which can pass information about previous characters too) so we need to build LSTM architecture which implements such inference. So we use keras functional API to build a custom model.
#
# We build a model by stacking keras layers on top of one another:
# 1. Input layer (specifying shape of input)
# - tensorflow.keras.layers.Input() class
# 2.
#
#
# LSTM_cell:
#
# Takes hidden state as input and returns the next hidden state
#
# dense_layer:
#
# Dense implements the operation: output = activation(dot(input, kernel) + bias) where:
# - activation = element-wise activation function passed as the activation argument
# - kernel = weights matrix created by the layer
# - bias = bias vector created by the layer
#
# Thus here we use Dense to calculated y_pred = softmax(dot(Wya, a) + by)

# %%
#define the layer objects of the model globally so that they are fixed when used in a model function

LSTM_cell = LSTM(n_a, return_state = True) #shape of output is n_a, and of weight n_a x input[0]

prediction_layer = Dense(vocab_size, activation='softmax')

reshape_layer = Reshape((1, vocab_size))

# %%
def LSTM_model(max_len, n_a, vocab_size):
    
    #specify the shape of input X
    X = Input(shape=(max_len, vocab_size))
    
    #specify the size of accepted a0 and c) inputs
    a0 = Input(shape=(n_a,), name='a0')
    c0 = Input(shape=(n_a,), name='c0')
    
    #initiliase cell state and hidden state
    a = a0
    c = c0
    
    #create an empty list to append predictions (outputs of Dense)
    outputs = []
    
    for t in range(max_len):
        
        #adds a layer for the next input (i.e. next character and next timestep)
        #lambda allows to specify the operation to be applied as a function on a tensor in a layer
        #here it just takes a slice of x for a given timestep and returns it
        x_t = Lambda(lambda x_t: X[:,t,:])(X) #each takes a slice of X as input so this is a slicing layer
        
        # reshapes x to be (1, vocab_size) 
        x_t = reshape_layer(x_t) #reshapes the slice
        
        #one step of LSTM to update hidden state and cell state
        a, _, c = LSTM_cell(x_t, initial_state=[c, a])
        
        #apply softmax to a function of hidden state to get prediction
        output = prediction_layer(a)
        
        outputs.append(output)
        
    model = Model(inputs= [X,a0,c0], outputs= outputs)
    
    return model

# %%
#def our model
model = LSTM_model(max_len = max_len , n_a = n_a, vocab_size = vocab_size)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 12, 15889)]  0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 15889)        0           input_1[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 15889)     0           lambda[0][0]
#                                                                  lambda_1[0][0]
#                                                                  lambda_2[0][0]
#                                                                  lambda_3[0][0]
#                                                                  lambda_4[0][0]
#                                                                  lambda_5[0][0]
#                                                                  lambda_6[0][0]
#                                                                  lambda_7[0][0]
#                                                                  lambda_8[0][0]
#                                                                  lambda_9[0][0]
#                                                                  lambda_10[0][0]
#                                                                  lambda_11[0][0]
# __________________________________________________________________________________________________
# c0 (InputLayer)                 [(None, 500)]        0
# __________________________________________________________________________________________________
# a0 (InputLayer)                 [(None, 500)]        0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 15889)        0           input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 500), (None, 32780000    reshape[0][0]
#                                                                  c0[0][0]
#                                                                  a0[0][0]
#                                                                  reshape[1][0]
#                                                                  lstm[0][2]
#                                                                  lstm[0][0]
#                                                                  reshape[2][0]
#                                                                  lstm[1][2]
#                                                                  lstm[1][0]
#                                                                  reshape[3][0]
#                                                                  lstm[2][2]
#                                                                  lstm[2][0]
#                                                                  reshape[4][0]
#                                                                  lstm[3][2]
#                                                                  lstm[3][0]
#                                                                  reshape[5][0]
#                                                                  lstm[4][2]
#                                                                  lstm[4][0]
#                                                                  reshape[6][0]
#                                                                  lstm[5][2]
#                                                                  lstm[5][0]
#                                                                  reshape[7][0]
#                                                                  lstm[6][2]
#                                                                  lstm[6][0]
#                                                                  reshape[8][0]
#                                                                  lstm[7][2]
#                                                                  lstm[7][0]
#                                                                  reshape[9][0]
#                                                                  lstm[8][2]
#                                                                  lstm[8][0]
#                                                                  reshape[10][0]
#                                                                  lstm[9][2]
#                                                                  lstm[9][0]
#                                                                  reshape[11][0]
#                                                                  lstm[10][2]
#                                                                  lstm[10][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 15889)        0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 15889)        0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 15889)        0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 15889)        0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 15889)        0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 15889)        0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 15889)        0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 15889)        0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 15889)        0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 15889)        0           input_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 15889)        7960389     lstm[0][0]
#                                                                  lstm[1][0]
#                                                                  lstm[2][0]
#                                                                  lstm[3][0]
#                                                                  lstm[4][0]
#                                                                  lstm[5][0]
#                                                                  lstm[6][0]
#                                                                  lstm[7][0]
#                                                                  lstm[8][0]
#                                                                  lstm[9][0]
#                                                                  lstm[10][0]
#                                                                  lstm[11][0]
# ==================================================================================================
# Total params: 40,740,389
# Trainable params: 40,740,389
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(model, "my_first_model_with_shape_info.png", show_shapes=True)

#should be seversl outputs and several lstm layers

# %%
#compile the model

optimizer = Adam(lr=0.01, beta_1=0.9, beta_2=0.9999, decay=0.001)

model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
k = n_haikus
a0 = np.zeros((k, n_a))
c0 = np.zeros((k, n_a))

# %%
history = model.fit([X, a0, c0], list(Y), epochs=35)
# Out:
# Train on 8394 samples
# Epoch 1/35
# 8394/8394 [==============================] - 438s 52ms/sample - loss: 83.6672 - dense_loss: 7.9855 - dense_1_loss: 6.0619 - dense_2_loss: 5.2416 - dense_3_loss: 6.9974 - dense_4_loss: 8.7892 - dense_5_loss: 8.8827 - dense_6_loss: 7.3640 - dense_7_loss: 5.3312 - dense_8_loss: 6.1733 - dense_9_loss: 8.4094 - dense_10_loss: 10.9784 - dense_11_loss: 1.4308 - dense_accuracy: 0.0442 - dense_1_accuracy: 0.3109 - dense_2_accuracy: 0.3993 - dense_3_accuracy: 0.2302 - dense_4_accuracy: 0.0120 - dense_5_accuracy: 0.0344 - dense_6_accuracy: 0.2274 - dense_7_accuracy: 0.4227 - dense_8_accuracy: 0.2731 - dense_9_accuracy: 0.0328 - dense_10_accuracy: 0.0000e+00 - dense_11_accuracy: 0.9923
# Epoch 2/35
# 8394/8394 [==============================] - 434s 52ms/sample - loss: 71.5981 - dense_loss: 6.3453 - dense_1_loss: 4.9704 - dense_2_loss: 4.5140 - dense_3_loss: 6.0754 - dense_4_loss: 7.7224 - dense_5_loss: 7.8037 - dense_6_loss: 6.5571 - dense_7_loss: 4.7369 - dense_8_loss: 5.3456 - dense_9_loss: 7.4310 - dense_10_loss: 9.5173 - dense_11_loss: 0.5786 - dense_accuracy: 0.0979 - dense_1_accuracy: 0.3199 - dense_2_accuracy: 0.4230 - dense_3_accuracy: 0.2411 - dense_4_accuracy: 0.0247 - dense_5_accuracy: 0.0409 - dense_6_accuracy: 0.2318 - dense_7_accuracy: 0.4260 - dense_8_accuracy: 0.2810 - dense_9_accuracy: 0.0549 - dense_10_accuracy: 0.0000e+00 - dense_11_accuracy: 0.9999
# Epoch 3/35
# 8394/8394 [==============================] - 440s 52ms/sample - loss: 66.6762 - dense_loss: 4.9837 - dense_1_loss: 4.2317 - dense_2_loss: 4.2061 - dense_3_loss: 5.7408 - dense_4_loss: 7.4502 - dense_5_loss: 7.5476 - dense_6_loss: 6.3045 - dense_7_loss: 4.5521 - dense_8_loss: 5.0858 - dense_9_loss: 7.1680 - dense_10_loss: 9.1151 - dense_11_loss: 0.3024 - dense_accuracy: 0.1779 - dense_1_accuracy: 0.3551 - dense_2_accuracy: 0.4467 - dense_3_accuracy: 0.2605 - dense_4_accuracy: 0.0496 - dense_5_accuracy: 0.0559 - dense_6_accuracy: 0.2353 - dense_7_accuracy: 0.4320 - dense_8_accuracy: 0.3000 - dense_9_accuracy: 0.0872 - dense_10_accuracy: 2.3827e-04 - dense_11_accuracy: 0.9999
# Epoch 4/35
# 8394/8394 [==============================] - 435s 52ms/sample - loss: 63.1020 - dense_loss: 3.6997 - dense_1_loss: 3.3571 - dense_2_loss: 3.9780 - dense_3_loss: 5.5890 - dense_4_loss: 7.2706 - dense_5_loss: 7.3796 - dense_6_loss: 6.1616 - dense_7_loss: 4.4752 - dense_8_loss: 4.9802 - dense_9_loss: 7.0349 - dense_10_loss: 8.9243 - dense_11_loss: 0.2596 - dense_accuracy: 0.2966 - dense_1_accuracy: 0.4168 - dense_2_accuracy: 0.4490 - dense_3_accuracy: 0.2664 - dense_4_accuracy: 0.0542 - dense_5_accuracy: 0.0622 - dense_6_accuracy: 0.2356 - dense_7_accuracy: 0.4372 - dense_8_accuracy: 0.3115 - dense_9_accuracy: 0.0901 - dense_10_accuracy: 1.1913e-04 - dense_11_accuracy: 0.9996
# Epoch 5/35
# 8394/8394 [==============================] - 425s 51ms/sample - loss: 59.8335 - dense_loss: 2.8230 - dense_1_loss: 2.4352 - dense_2_loss: 3.7425 - dense_3_loss: 5.4190 - dense_4_loss: 7.1083 - dense_5_loss: 7.2230 - dense_6_loss: 6.0249 - dense_7_loss: 4.3870 - dense_8_loss: 4.8814 - dense_9_loss: 6.8684 - dense_10_loss: 8.6910 - dense_11_loss: 0.2341 - dense_accuracy: 0.3941 - dense_1_accuracy: 0.5099 - dense_2_accuracy: 0.4537 - dense_3_accuracy: 0.2721 - dense_4_accuracy: 0.0624 - dense_5_accuracy: 0.0662 - dense_6_accuracy: 0.2392 - dense_7_accuracy: 0.4386 - dense_8_accuracy: 0.3242 - dense_9_accuracy: 0.0964 - dense_10_accuracy: 2.3827e-04 - dense_11_accuracy: 0.9998
# Epoch 6/35
# 8394/8394 [==============================] - 425s 51ms/sample - loss: 57.5948 - dense_loss: 2.4346 - dense_1_loss: 1.6641 - dense_2_loss: 3.5414 - dense_3_loss: 5.2765 - dense_4_loss: 6.9827 - dense_5_loss: 7.1042 - dense_6_loss: 5.8998 - dense_7_loss: 4.3062 - dense_8_loss: 4.8053 - dense_9_loss: 6.7820 - dense_10_loss: 8.5707 - dense_11_loss: 0.2307 - dense_accuracy: 0.4084 - dense_1_accuracy: 0.6353 - dense_2_accuracy: 0.4652 - dense_3_accuracy: 0.2765 - dense_4_accuracy: 0.0633 - dense_5_accuracy: 0.0679 - dense_6_accuracy: 0.2403 - dense_7_accuracy: 0.4394 - dense_8_accuracy: 0.3251 - dense_9_accuracy: 0.0997 - dense_10_accuracy: 2.3827e-04 - dense_11_accuracy: 0.9996
# Epoch 7/35
# 8394/8394 [==============================] - 427s 51ms/sample - loss: 55.4868 - dense_loss: 2.2924 - dense_1_loss: 1.1343 - dense_2_loss: 3.2664 - dense_3_loss: 5.1115 - dense_4_loss: 6.8054 - dense_5_loss: 6.9404 - dense_6_loss: 5.7640 - dense_7_loss: 4.2144 - dense_8_loss: 4.7172 - dense_9_loss: 6.6437 - dense_10_loss: 8.3969 - dense_11_loss: 0.2004 - dense_accuracy: 0.4095 - dense_1_accuracy: 0.7325 - dense_2_accuracy: 0.4768 - dense_3_accuracy: 0.2797 - dense_4_accuracy: 0.0660 - dense_5_accuracy: 0.0728 - dense_6_accuracy: 0.2395 - dense_7_accuracy: 0.4390 - dense_8_accuracy: 0.3288 - dense_9_accuracy: 0.0997 - dense_10_accuracy: 2.3827e-04 - dense_11_accuracy: 0.9999
# Epoch 8/35
# 8394/8394 [==============================] - 1777s 212ms/sample - loss: 53.7296 - dense_loss: 2.2015 - dense_1_loss: 0.8273 - dense_2_loss: 3.0069 - dense_3_loss: 4.9313 - dense_4_loss: 6.6306 - dense_5_loss: 6.7849 - dense_6_loss: 5.6423 - dense_7_loss: 4.1240 - dense_8_loss: 4.6383 - dense_9_loss: 6.5340 - dense_10_loss: 8.2203 - dense_11_loss: 0.1827 - dense_accuracy: 0.4056 - dense_1_accuracy: 0.7951 - dense_2_accuracy: 0.4923 - dense_3_accuracy: 0.2807 - dense_4_accuracy: 0.0718 - dense_5_accuracy: 0.0743 - dense_6_accuracy: 0.2399 - dense_7_accuracy: 0.4391 - dense_8_accuracy: 0.3293 - dense_9_accuracy: 0.1015 - dense_10_accuracy: 3.5740e-04 - dense_11_accuracy: 1.0000
# Epoch 9/35
# 8394/8394 [==============================] - 428s 51ms/sample - loss: 52.0343 - dense_loss: 2.1455 - dense_1_loss: 0.6772 - dense_2_loss: 2.7242 - dense_3_loss: 4.7531 - dense_4_loss: 6.4450 - dense_5_loss: 6.6155 - dense_6_loss: 5.5175 - dense_7_loss: 4.0153 - dense_8_loss: 4.5563 - dense_9_loss: 6.4177 - dense_10_loss: 8.0128 - dense_11_loss: 0.1624 - dense_accuracy: 0.4114 - dense_1_accuracy: 0.8258 - dense_2_accuracy: 0.5213 - dense_3_accuracy: 0.2850 - dense_4_accuracy: 0.0762 - dense_5_accuracy: 0.0774 - dense_6_accuracy: 0.2405 - dense_7_accuracy: 0.4396 - dense_8_accuracy: 0.3295 - dense_9_accuracy: 0.1016 - dense_10_accuracy: 0.0012 - dense_11_accuracy: 0.9998
# Epoch 10/35
# 8394/8394 [==============================] - 437s 52ms/sample - loss: 50.4656 - dense_loss: 2.1009 - dense_1_loss: 0.5730 - dense_2_loss: 2.4260 - dense_3_loss: 4.5590 - dense_4_loss: 6.2835 - dense_5_loss: 6.4744 - dense_6_loss: 5.4063 - dense_7_loss: 3.9123 - dense_8_loss: 4.4752 - dense_9_loss: 6.3047 - dense_10_loss: 7.8277 - dense_11_loss: 0.1311 - dense_accuracy: 0.4123 - dense_1_accuracy: 0.8495 - dense_2_accuracy: 0.5584 - dense_3_accuracy: 0.2924 - dense_4_accuracy: 0.0790 - dense_5_accuracy: 0.0814 - dense_6_accuracy: 0.2452 - dense_7_accuracy: 0.4397 - dense_8_accuracy: 0.3314 - dense_9_accuracy: 0.1032 - dense_10_accuracy: 0.0023 - dense_11_accuracy: 0.9999
# Epoch 11/35
# 8394/8394 [==============================] - 429s 51ms/sample - loss: 48.8547 - dense_loss: 2.0663 - dense_1_loss: 0.5109 - dense_2_loss: 2.1121 - dense_3_loss: 4.3524 - dense_4_loss: 6.1044 - dense_5_loss: 6.3092 - dense_6_loss: 5.2677 - dense_7_loss: 3.7991 - dense_8_loss: 4.4017 - dense_9_loss: 6.1941 - dense_10_loss: 7.6448 - dense_11_loss: 0.0939 - dense_accuracy: 0.4137 - dense_1_accuracy: 0.8623 - dense_2_accuracy: 0.6038 - dense_3_accuracy: 0.2997 - dense_4_accuracy: 0.0802 - dense_5_accuracy: 0.0863 - dense_6_accuracy: 0.2468 - dense_7_accuracy: 0.4403 - dense_8_accuracy: 0.3325 - dense_9_accuracy: 0.1054 - dense_10_accuracy: 0.0039 - dense_11_accuracy: 0.9999
# Epoch 12/35
# 8394/8394 [==============================] - 428s 51ms/sample - loss: 47.2360 - dense_loss: 2.0382 - dense_1_loss: 0.4767 - dense_2_loss: 1.8265 - dense_3_loss: 4.1098 - dense_4_loss: 5.9246 - dense_5_loss: 6.1493 - dense_6_loss: 5.1340 - dense_7_loss: 3.6871 - dense_8_loss: 4.3127 - dense_9_loss: 6.0672 - dense_10_loss: 7.4443 - dense_11_loss: 0.0671 - dense_accuracy: 0.4116 - dense_1_accuracy: 0.8655 - dense_2_accuracy: 0.6483 - dense_3_accuracy: 0.3155 - dense_4_accuracy: 0.0873 - dense_5_accuracy: 0.0864 - dense_6_accuracy: 0.2486 - dense_7_accuracy: 0.4426 - dense_8_accuracy: 0.3348 - dense_9_accuracy: 0.1064 - dense_10_accuracy: 0.0061 - dense_11_accuracy: 0.9999
# Epoch 13/35
# 8394/8394 [==============================] - 429s 51ms/sample - loss: 45.7896 - dense_loss: 2.0160 - dense_1_loss: 0.4513 - dense_2_loss: 1.5809 - dense_3_loss: 3.8583 - dense_4_loss: 5.7432 - dense_5_loss: 6.0032 - dense_6_loss: 5.0297 - dense_7_loss: 3.6048 - dense_8_loss: 4.2429 - dense_9_loss: 5.9440 - dense_10_loss: 7.2767 - dense_11_loss: 0.0498 - dense_accuracy: 0.4183 - dense_1_accuracy: 0.8667 - dense_2_accuracy: 0.6856 - dense_3_accuracy: 0.3426 - dense_4_accuracy: 0.0972 - dense_5_accuracy: 0.0922 - dense_6_accuracy: 0.2507 - dense_7_accuracy: 0.4459 - dense_8_accuracy: 0.3367 - dense_9_accuracy: 0.1086 - dense_10_accuracy: 0.0076 - dense_11_accuracy: 1.0000
# Epoch 14/35
# 8394/8394 [==============================] - 429s 51ms/sample - loss: 44.6582 - dense_loss: 1.9959 - dense_1_loss: 0.4393 - dense_2_loss: 1.3729 - dense_3_loss: 3.6334 - dense_4_loss: 5.6192 - dense_5_loss: 5.9138 - dense_6_loss: 4.9405 - dense_7_loss: 3.5259 - dense_8_loss: 4.1684 - dense_9_loss: 5.8622 - dense_10_loss: 7.1491 - dense_11_loss: 0.0422 - dense_accuracy: 0.4178 - dense_1_accuracy: 0.8675 - dense_2_accuracy: 0.7254 - dense_3_accuracy: 0.3622 - dense_4_accuracy: 0.1081 - dense_5_accuracy: 0.0991 - dense_6_accuracy: 0.2535 - dense_7_accuracy: 0.4475 - dense_8_accuracy: 0.3387 - dense_9_accuracy: 0.1126 - dense_10_accuracy: 0.0113 - dense_11_accuracy: 0.9998
# Epoch 15/35
# 8394/8394 [==============================] - 428s 51ms/sample - loss: 42.8938 - dense_loss: 1.9747 - dense_1_loss: 0.4080 - dense_2_loss: 1.1465 - dense_3_loss: 3.3185 - dense_4_loss: 5.3864 - dense_5_loss: 5.7118 - dense_6_loss: 4.7836 - dense_7_loss: 3.4244 - dense_8_loss: 4.0541 - dense_9_loss: 5.7086 - dense_10_loss: 6.9382 - dense_11_loss: 0.0375 - dense_accuracy: 0.4202 - dense_1_accuracy: 0.8711 - dense_2_accuracy: 0.7617 - dense_3_accuracy: 0.4027 - dense_4_accuracy: 0.1208 - dense_5_accuracy: 0.1038 - dense_6_accuracy: 0.2567 - dense_7_accuracy: 0.4507 - dense_8_accuracy: 0.3429 - dense_9_accuracy: 0.1166 - dense_10_accuracy: 0.0142 - dense_11_accuracy: 0.9999
# Epoch 16/35
# 8394/8394 [==============================] - 428s 51ms/sample - loss: 41.5712 - dense_loss: 1.9590 - dense_1_loss: 0.3887 - dense_2_loss: 0.9862 - dense_3_loss: 3.0228 - dense_4_loss: 5.1947 - dense_5_loss: 5.5862 - dense_6_loss: 4.6811 - dense_7_loss: 3.3423 - dense_8_loss: 3.9878 - dense_9_loss: 5.6017 - dense_10_loss: 6.7877 - dense_11_loss: 0.0337 - dense_accuracy: 0.4166 - dense_1_accuracy: 0.8730 - dense_2_accuracy: 0.7970 - dense_3_accuracy: 0.4473 - dense_4_accuracy: 0.1358 - dense_5_accuracy: 0.1069 - dense_6_accuracy: 0.2616 - dense_7_accuracy: 0.4535 - dense_8_accuracy: 0.3476 - dense_9_accuracy: 0.1214 - dense_10_accuracy: 0.0180 - dense_11_accuracy: 0.9998
# Epoch 17/35
# 8394/8394 [==============================] - 429s 51ms/sample - loss: 40.1389 - dense_loss: 1.9486 - dense_1_loss: 0.3808 - dense_2_loss: 0.8391 - dense_3_loss: 2.7236 - dense_4_loss: 4.9714 - dense_5_loss: 5.4290 - dense_6_loss: 4.5581 - dense_7_loss: 3.2605 - dense_8_loss: 3.8897 - dense_9_loss: 5.4799 - dense_10_loss: 6.6154 - dense_11_loss: 0.0281 - dense_accuracy: 0.4203 - dense_1_accuracy: 0.8697 - dense_2_accuracy: 0.8237 - dense_3_accuracy: 0.4959 - dense_4_accuracy: 0.1563 - dense_5_accuracy: 0.1166 - dense_6_accuracy: 0.2677 - dense_7_accuracy: 0.4569 - dense_8_accuracy: 0.3487 - dense_9_accuracy: 0.1263 - dense_10_accuracy: 0.0232 - dense_11_accuracy: 1.0000
# Epoch 18/35
# 8394/8394 [==============================] - 426s 51ms/sample - loss: 38.9528 - dense_loss: 1.9340 - dense_1_loss: 0.3729 - dense_2_loss: 0.7526 - dense_3_loss: 2.4807 - dense_4_loss: 4.7701 - dense_5_loss: 5.2867 - dense_6_loss: 4.4585 - dense_7_loss: 3.1842 - dense_8_loss: 3.8327 - dense_9_loss: 5.3919 - dense_10_loss: 6.4586 - dense_11_loss: 0.0251 - dense_accuracy: 0.4249 - dense_1_accuracy: 0.8716 - dense_2_accuracy: 0.8417 - dense_3_accuracy: 0.5421 - dense_4_accuracy: 0.1830 - dense_5_accuracy: 0.1277 - dense_6_accuracy: 0.2707 - dense_7_accuracy: 0.4604 - dense_8_accuracy: 0.3499 - dense_9_accuracy: 0.1365 - dense_10_accuracy: 0.0338 - dense_11_accuracy: 1.0000
# Epoch 19/35
# 8394/8394 [==============================] - 428s 51ms/sample - loss: 37.5862 - dense_loss: 1.9249 - dense_1_loss: 0.3630 - dense_2_loss: 0.6422 - dense_3_loss: 2.2147 - dense_4_loss: 4.5331 - dense_5_loss: 5.1254 - dense_6_loss: 4.3435 - dense_7_loss: 3.1055 - dense_8_loss: 3.7450 - dense_9_loss: 5.2685 - dense_10_loss: 6.2919 - dense_11_loss: 0.0249 - dense_accuracy: 0.4204 - dense_1_accuracy: 0.8738 - dense_2_accuracy: 0.8600 - dense_3_accuracy: 0.5901 - dense_4_accuracy: 0.2128 - dense_5_accuracy: 0.1384 - dense_6_accuracy: 0.2831 - dense_7_accuracy: 0.4604 - dense_8_accuracy: 0.3548 - dense_9_accuracy: 0.1433 - dense_10_accuracy: 0.0436 - dense_11_accuracy: 0.9998
# Epoch 20/35
# 8394/8394 [==============================] - 431s 51ms/sample - loss: 36.0984 - dense_loss: 1.9094 - dense_1_loss: 0.3494 - dense_2_loss: 0.5562 - dense_3_loss: 1.9540 - dense_4_loss: 4.2593 - dense_5_loss: 4.9304 - dense_6_loss: 4.2061 - dense_7_loss: 3.0238 - dense_8_loss: 3.6489 - dense_9_loss: 5.1296 - dense_10_loss: 6.0998 - dense_11_loss: 0.0202 - dense_accuracy: 0.4226 - dense_1_accuracy: 0.8715 - dense_2_accuracy: 0.8777 - dense_3_accuracy: 0.6313 - dense_4_accuracy: 0.2479 - dense_5_accuracy: 0.1555 - dense_6_accuracy: 0.2933 - dense_7_accuracy: 0.4674 - dense_8_accuracy: 0.3620 - dense_9_accuracy: 0.1555 - dense_10_accuracy: 0.0590 - dense_11_accuracy: 0.9998
# Epoch 21/35
# 8394/8394 [==============================] - 428s 51ms/sample - loss: 34.5592 - dense_loss: 1.9048 - dense_1_loss: 0.3415 - dense_2_loss: 0.4920 - dense_3_loss: 1.7159 - dense_4_loss: 3.9674 - dense_5_loss: 4.7065 - dense_6_loss: 4.0606 - dense_7_loss: 2.9290 - dense_8_loss: 3.5586 - dense_9_loss: 4.9795 - dense_10_loss: 5.8835 - dense_11_loss: 0.0175 - dense_accuracy: 0.4245 - dense_1_accuracy: 0.8716 - dense_2_accuracy: 0.8897 - dense_3_accuracy: 0.6775 - dense_4_accuracy: 0.2944 - dense_5_accuracy: 0.1863 - dense_6_accuracy: 0.3089 - dense_7_accuracy: 0.4734 - dense_8_accuracy: 0.3718 - dense_9_accuracy: 0.1721 - dense_10_accuracy: 0.0826 - dense_11_accuracy: 0.9995
# Epoch 22/35
# 8394/8394 [==============================] - 435s 52ms/sample - loss: 33.1307 - dense_loss: 1.8909 - dense_1_loss: 0.3307 - dense_2_loss: 0.4404 - dense_3_loss: 1.5257 - dense_4_loss: 3.6841 - dense_5_loss: 4.4817 - dense_6_loss: 3.9161 - dense_7_loss: 2.8573 - dense_8_loss: 3.4696 - dense_9_loss: 4.8305 - dense_10_loss: 5.6676 - dense_11_loss: 0.0168 - dense_accuracy: 0.4272 - dense_1_accuracy: 0.8729 - dense_2_accuracy: 0.8981 - dense_3_accuracy: 0.7125 - dense_4_accuracy: 0.3333 - dense_5_accuracy: 0.2148 - dense_6_accuracy: 0.3226 - dense_7_accuracy: 0.4826 - dense_8_accuracy: 0.3807 - dense_9_accuracy: 0.1860 - dense_10_accuracy: 0.1086 - dense_11_accuracy: 0.9995
# Epoch 23/35
# 8394/8394 [==============================] - 428s 51ms/sample - loss: 31.6845 - dense_loss: 1.8880 - dense_1_loss: 0.3259 - dense_2_loss: 0.3972 - dense_3_loss: 1.3583 - dense_4_loss: 3.4212 - dense_5_loss: 4.2598 - dense_6_loss: 3.7659 - dense_7_loss: 2.7560 - dense_8_loss: 3.3640 - dense_9_loss: 4.6880 - dense_10_loss: 5.4557 - dense_11_loss: 0.0134 - dense_accuracy: 0.4280 - dense_1_accuracy: 0.8728 - dense_2_accuracy: 0.9083 - dense_3_accuracy: 0.7486 - dense_4_accuracy: 0.3747 - dense_5_accuracy: 0.2505 - dense_6_accuracy: 0.3470 - dense_7_accuracy: 0.4918 - dense_8_accuracy: 0.3905 - dense_9_accuracy: 0.2004 - dense_10_accuracy: 0.1391 - dense_11_accuracy: 0.9994
# Epoch 24/35
# 8394/8394 [==============================] - 430s 51ms/sample - loss: 30.3083 - dense_loss: 1.8801 - dense_1_loss: 0.3237 - dense_2_loss: 0.3596 - dense_3_loss: 1.2034 - dense_4_loss: 3.1402 - dense_5_loss: 4.0310 - dense_6_loss: 3.6177 - dense_7_loss: 2.6765 - dense_8_loss: 3.2653 - dense_9_loss: 4.5311 - dense_10_loss: 5.2691 - dense_11_loss: 0.0128 - dense_accuracy: 0.4229 - dense_1_accuracy: 0.8749 - dense_2_accuracy: 0.9153 - dense_3_accuracy: 0.7734 - dense_4_accuracy: 0.4218 - dense_5_accuracy: 0.2871 - dense_6_accuracy: 0.3647 - dense_7_accuracy: 0.5007 - dense_8_accuracy: 0.4009 - dense_9_accuracy: 0.2203 - dense_10_accuracy: 0.1708 - dense_11_accuracy: 0.9999
# Epoch 25/35
# 8394/8394 [==============================] - 428s 51ms/sample - loss: 28.9844 - dense_loss: 1.8726 - dense_1_loss: 0.3163 - dense_2_loss: 0.3317 - dense_3_loss: 1.0809 - dense_4_loss: 2.8905 - dense_5_loss: 3.7946 - dense_6_loss: 3.4623 - dense_7_loss: 2.5948 - dense_8_loss: 3.1753 - dense_9_loss: 4.3989 - dense_10_loss: 5.0608 - dense_11_loss: 0.0135 - dense_accuracy: 0.4292 - dense_1_accuracy: 0.8749 - dense_2_accuracy: 0.9168 - dense_3_accuracy: 0.8016 - dense_4_accuracy: 0.4619 - dense_5_accuracy: 0.3159 - dense_6_accuracy: 0.3919 - dense_7_accuracy: 0.5154 - dense_8_accuracy: 0.4141 - dense_9_accuracy: 0.2423 - dense_10_accuracy: 0.1966 - dense_11_accuracy: 0.9995
# Epoch 26/35
# 8394/8394 [==============================] - 428s 51ms/sample - loss: 28.4122 - dense_loss: 1.8702 - dense_1_loss: 0.3253 - dense_2_loss: 0.3449 - dense_3_loss: 1.0554 - dense_4_loss: 2.7812 - dense_5_loss: 3.6710 - dense_6_loss: 3.3879 - dense_7_loss: 2.5479 - dense_8_loss: 3.1276 - dense_9_loss: 4.3341 - dense_10_loss: 4.9577 - dense_11_loss: 0.0142 - dense_accuracy: 0.4245 - dense_1_accuracy: 0.8746 - dense_2_accuracy: 0.9185 - dense_3_accuracy: 0.8058 - dense_4_accuracy: 0.4843 - dense_5_accuracy: 0.3443 - dense_6_accuracy: 0.4040 - dense_7_accuracy: 0.5241 - dense_8_accuracy: 0.4214 - dense_9_accuracy: 0.2511 - dense_10_accuracy: 0.2115 - dense_11_accuracy: 0.9998
# Epoch 27/35
# 8394/8394 [==============================] - 428s 51ms/sample - loss: 27.2326 - dense_loss: 1.8680 - dense_1_loss: 0.3191 - dense_2_loss: 0.3254 - dense_3_loss: 0.9571 - dense_4_loss: 2.5956 - dense_5_loss: 3.4411 - dense_6_loss: 3.2322 - dense_7_loss: 2.4614 - dense_8_loss: 3.0432 - dense_9_loss: 4.2065 - dense_10_loss: 4.7753 - dense_11_loss: 0.0142 - dense_accuracy: 0.4304 - dense_1_accuracy: 0.8750 - dense_2_accuracy: 0.9210 - dense_3_accuracy: 0.8250 - dense_4_accuracy: 0.5220 - dense_5_accuracy: 0.3778 - dense_6_accuracy: 0.4267 - dense_7_accuracy: 0.5360 - dense_8_accuracy: 0.4347 - dense_9_accuracy: 0.2690 - dense_10_accuracy: 0.2437 - dense_11_accuracy: 0.9993
# Epoch 28/35
# 8394/8394 [==============================] - 429s 51ms/sample - loss: 25.4642 - dense_loss: 1.8587 - dense_1_loss: 0.3061 - dense_2_loss: 0.2791 - dense_3_loss: 0.8121 - dense_4_loss: 2.2759 - dense_5_loss: 3.1389 - dense_6_loss: 3.0042 - dense_7_loss: 2.3393 - dense_8_loss: 2.9229 - dense_9_loss: 4.0279 - dense_10_loss: 4.4912 - dense_11_loss: 0.0115 - dense_accuracy: 0.4263 - dense_1_accuracy: 0.8753 - dense_2_accuracy: 0.9296 - dense_3_accuracy: 0.8511 - dense_4_accuracy: 0.5778 - dense_5_accuracy: 0.4328 - dense_6_accuracy: 0.4646 - dense_7_accuracy: 0.5584 - dense_8_accuracy: 0.4498 - dense_9_accuracy: 0.2977 - dense_10_accuracy: 0.2896 - dense_11_accuracy: 0.9995
# Epoch 29/35
# 8394/8394 [==============================] - 428s 51ms/sample - loss: 24.0055 - dense_loss: 1.8537 - dense_1_loss: 0.3010 - dense_2_loss: 0.2535 - dense_3_loss: 0.7134 - dense_4_loss: 2.0492 - dense_5_loss: 2.8798 - dense_6_loss: 2.8142 - dense_7_loss: 2.2308 - dense_8_loss: 2.8157 - dense_9_loss: 3.8583 - dense_10_loss: 4.2412 - dense_11_loss: 0.0108 - dense_accuracy: 0.4283 - dense_1_accuracy: 0.8753 - dense_2_accuracy: 0.9345 - dense_3_accuracy: 0.8717 - dense_4_accuracy: 0.6215 - dense_5_accuracy: 0.4781 - dense_6_accuracy: 0.4946 - dense_7_accuracy: 0.5767 - dense_8_accuracy: 0.4678 - dense_9_accuracy: 0.3165 - dense_10_accuracy: 0.3244 - dense_11_accuracy: 0.9998
# Epoch 30/35
# 8394/8394 [==============================] - 428s 51ms/sample - loss: 22.6436 - dense_loss: 1.8467 - dense_1_loss: 0.3018 - dense_2_loss: 0.2368 - dense_3_loss: 0.6303 - dense_4_loss: 1.8458 - dense_5_loss: 2.6394 - dense_6_loss: 2.6331 - dense_7_loss: 2.1160 - dense_8_loss: 2.6971 - dense_9_loss: 3.6959 - dense_10_loss: 3.9976 - dense_11_loss: 0.0098 - dense_accuracy: 0.4302 - dense_1_accuracy: 0.8729 - dense_2_accuracy: 0.9357 - dense_3_accuracy: 0.8866 - dense_4_accuracy: 0.6617 - dense_5_accuracy: 0.5181 - dense_6_accuracy: 0.5269 - dense_7_accuracy: 0.5938 - dense_8_accuracy: 0.4894 - dense_9_accuracy: 0.3411 - dense_10_accuracy: 0.3607 - dense_11_accuracy: 0.9996
# Epoch 31/35
# 8394/8394 [==============================] - 428s 51ms/sample - loss: 21.3961 - dense_loss: 1.8428 - dense_1_loss: 0.2930 - dense_2_loss: 0.2267 - dense_3_loss: 0.5729 - dense_4_loss: 1.6746 - dense_5_loss: 2.4261 - dense_6_loss: 2.4501 - dense_7_loss: 1.9973 - dense_8_loss: 2.5970 - dense_9_loss: 3.5276 - dense_10_loss: 3.7757 - dense_11_loss: 0.0084 - dense_accuracy: 0.4265 - dense_1_accuracy: 0.8766 - dense_2_accuracy: 0.9348 - dense_3_accuracy: 0.8984 - dense_4_accuracy: 0.6930 - dense_5_accuracy: 0.5599 - dense_6_accuracy: 0.5527 - dense_7_accuracy: 0.6144 - dense_8_accuracy: 0.5030 - dense_9_accuracy: 0.3663 - dense_10_accuracy: 0.3909 - dense_11_accuracy: 0.9999
# Epoch 32/35
# 8394/8394 [==============================] - 428s 51ms/sample - loss: 20.1842 - dense_loss: 1.8384 - dense_1_loss: 0.2916 - dense_2_loss: 0.2171 - dense_3_loss: 0.5158 - dense_4_loss: 1.5096 - dense_5_loss: 2.2243 - dense_6_loss: 2.2671 - dense_7_loss: 1.8947 - dense_8_loss: 2.4835 - dense_9_loss: 3.3789 - dense_10_loss: 3.5492 - dense_11_loss: 0.0084 - dense_accuracy: 0.4291 - dense_1_accuracy: 0.8744 - dense_2_accuracy: 0.9369 - dense_3_accuracy: 0.9079 - dense_4_accuracy: 0.7300 - dense_5_accuracy: 0.5940 - dense_6_accuracy: 0.5834 - dense_7_accuracy: 0.6333 - dense_8_accuracy: 0.5229 - dense_9_accuracy: 0.3886 - dense_10_accuracy: 0.4238 - dense_11_accuracy: 0.9998
# Epoch 33/35
# 8394/8394 [==============================] - 427s 51ms/sample - loss: 19.1106 - dense_loss: 1.8315 - dense_1_loss: 0.2909 - dense_2_loss: 0.2109 - dense_3_loss: 0.4812 - dense_4_loss: 1.3736 - dense_5_loss: 2.0366 - dense_6_loss: 2.1257 - dense_7_loss: 1.7963 - dense_8_loss: 2.3852 - dense_9_loss: 3.2292 - dense_10_loss: 3.3344 - dense_11_loss: 0.0105 - dense_accuracy: 0.4336 - dense_1_accuracy: 0.8740 - dense_2_accuracy: 0.9390 - dense_3_accuracy: 0.9184 - dense_4_accuracy: 0.7590 - dense_5_accuracy: 0.6319 - dense_6_accuracy: 0.6090 - dense_7_accuracy: 0.6495 - dense_8_accuracy: 0.5391 - dense_9_accuracy: 0.4062 - dense_10_accuracy: 0.4509 - dense_11_accuracy: 0.9993
# Epoch 34/35
# 8394/8394 [==============================] - 428s 51ms/sample - loss: 17.9151 - dense_loss: 1.8266 - dense_1_loss: 0.2866 - dense_2_loss: 0.2015 - dense_3_loss: 0.4345 - dense_4_loss: 1.2395 - dense_5_loss: 1.8553 - dense_6_loss: 1.9524 - dense_7_loss: 1.6767 - dense_8_loss: 2.2615 - dense_9_loss: 3.0697 - dense_10_loss: 3.1062 - dense_11_loss: 0.0070 - dense_accuracy: 0.4294 - dense_1_accuracy: 0.8762 - dense_2_accuracy: 0.9400 - dense_3_accuracy: 0.9255 - dense_4_accuracy: 0.7903 - dense_5_accuracy: 0.6702 - dense_6_accuracy: 0.6430 - dense_7_accuracy: 0.6713 - dense_8_accuracy: 0.5609 - dense_9_accuracy: 0.4370 - dense_10_accuracy: 0.4907 - dense_11_accuracy: 0.9998
# Epoch 35/35
# 8394/8394 [==============================] - 429s 51ms/sample - loss: 16.8574 - dense_loss: 1.8276 - dense_1_loss: 0.2844 - dense_2_loss: 0.1910 - dense_3_loss: 0.3921 - dense_4_loss: 1.1169 - dense_5_loss: 1.6908 - dense_6_loss: 1.8049 - dense_7_loss: 1.5828 - dense_8_loss: 2.1454 - dense_9_loss: 2.9217 - dense_10_loss: 2.9020 - dense_11_loss: 0.0070 - dense_accuracy: 0.4322 - dense_1_accuracy: 0.8761 - dense_2_accuracy: 0.9390 - dense_3_accuracy: 0.9333 - dense_4_accuracy: 0.8120 - dense_5_accuracy: 0.7060 - dense_6_accuracy: 0.6707 - dense_7_accuracy: 0.6922 - dense_8_accuracy: 0.5820 - dense_9_accuracy: 0.4603 - dense_10_accuracy: 0.5241 - dense_11_accuracy: 0.9996

# %%
path = os.getcwd()+'/LSTMmodel'
model.save(path)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-28-6c2e79b90101> in <module>
#       1 path = os.getcwd()+'/LSTMmodel'
# ----> 2 model.save(path)
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in save(self, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#    2000     # pylint: enable=line-too-long
#    2001     save.save_model(self, filepath, overwrite, include_optimizer, save_format,
# -> 2002                     signatures, options, save_traces)
#    2003
#    2004   def save_weights(self,
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/keras/saving/save.py in save_model(model, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#     155   else:
#     156     saved_model_save.save(model, filepath, overwrite, include_optimizer,
# --> 157                           signatures, options, save_traces)
#     158
#     159
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/keras/saving/saved_model/save.py in save(model, filepath, overwrite, include_optimizer, signatures, options, save_traces)
#      87     with distribution_strategy_context._get_default_replica_context():  # pylint: disable=protected-access
#      88       with utils.keras_option_scope(save_traces):
# ---> 89         save_lib.save(model, filepath, signatures, options)
#      90
#      91   if not include_optimizer:
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/saved_model/save.py in save(obj, export_dir, signatures, options)
#    1031
#    1032   _, exported_graph, object_saver, asset_info = _build_meta_graph(
# -> 1033       obj, signatures, options, meta_graph_def)
#    1034   saved_model.saved_model_schema_version = constants.SAVED_MODEL_SCHEMA_VERSION
#    1035
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/saved_model/save.py in _build_meta_graph(obj, signatures, options, meta_graph_def)
#    1196
#    1197   with save_context.save_context(options):
# -> 1198     return _build_meta_graph_impl(obj, signatures, options, meta_graph_def)
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/saved_model/save.py in _build_meta_graph_impl(obj, signatures, options, meta_graph_def)
#    1151   asset_info, exported_graph = _fill_meta_graph_def(meta_graph_def,
#    1152                                                     saveable_view, signatures,
# -> 1153                                                     options.namespace_whitelist)
#    1154   if options.function_aliases:
#    1155     function_aliases = meta_graph_def.meta_info_def.function_aliases
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/saved_model/save.py in _fill_meta_graph_def(meta_graph_def, saveable_view, signature_functions, namespace_whitelist)
#     685
#     686   with exported_graph.as_default():
# --> 687     signatures = _generate_signatures(signature_functions, resource_map)
#     688     for concrete_function in saveable_view.concrete_functions:
#     689       concrete_function.add_to_graph()
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/saved_model/save.py in _generate_signatures(signature_functions, resource_map)
#     551                                                   signature_key, function.name))
#     552     outputs = _call_function_with_mapped_captures(
# --> 553         function, mapped_inputs, resource_map)
#     554     signatures[signature_key] = signature_def_utils.build_signature_def(
#     555         _tensor_dict_to_tensorinfo(exterior_argument_placeholders),
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/saved_model/save.py in _call_function_with_mapped_captures(function, args, resource_map)
#     503   """Calls `function` in the exported graph, using mapped resource captures."""
#     504   export_captures = _map_captures_to_created_tensors(function.graph.captures,
# --> 505                                                      resource_map)
#     506   # Calls the function quite directly, since we have new captured resource
#     507   # tensors we need to feed in which weren't part of the original function
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/saved_model/save.py in _map_captures_to_created_tensors(original_captures, resource_map)
#     426            "(from gc.get_referrers, limited to two hops):\n{}"
#     427           ).format(interior,
# --> 428                    "\n".join([repr(obj) for obj in trackable_referrers])))
#     429     export_captures.append(mapped_resource)
#     430   return export_captures
#
# AssertionError: Tried to export a function which references untracked resource Tensor("input_1_1:0", shape=(None, 12, 15889), dtype=float32).TensorFlow objects (e.g. tf.Variable) captured by functions must be tracked by assigning them to an attribute of a tracked object or assigned to an attribute of the main object directly.
#
# Trackable Python objects referring to this tensor (from gc.get_referrers, limited to two hops):

# %% [markdown]
# ## Sampling with temperature

# %%
def sample_vec(prob_vec, temperature):
    #prob_vec = np.array(prob_vec).as_type('float64')
    prob_vec = tf.math.divide(tf.math.log(prob_vec),temperature)
    exp_prob_vec = tf.math.exp(prob_vec)
    p = tf.math.divide(exp_prob_vec, tf.math.reduce_sum(exp_prob_vec)) #normalize
    
    dist = tfp.distributions.Multinomial(total_count = 1, probs = p) #draw samples from multinomial dsitribution with p = prob, of given output
    sample = dist.sample()
    print(sample.shape)
    print(sample)
    
    y = K.argmax(sample)
    y = tf.one_hot(indices=y, depth= vocab_size)
    y = RepeatVector(1)(y) 
    print(y.shape)
    return y

# %%
#?

def sample_vec2(prob_vec, temperature):
    tfp.distributions.ExpRelaxedOneHotCategorical(
    temperature, logits=None, probs=None, validate_args=False, allow_nan_stats=True,
    name='ExpRelaxedOneHotCategorical'
)

# %%
def generate_sequence(LSTM_cell, prediction_layer, n_values = vocab_size, n_a = n_a, length = max_len, temperature = 1):
    
    x0 = Input(shape=(1, n_values))
    
    a0 = Input(shape=(n_a,), name='a0')
    c0 = Input(shape=(n_a,), name='c0')
    
    a = a0
    c = c0
    x = x0
    
    outputs = []
    
    for t in range(length):
        x = reshape_layer(x)
        a, _, c = LSTM_cell(x, initial_state=[a, c]) #or [c,a]
        pred = prediction_layer(a)
        y = Lambda(lambda a: sample_vec(a,temperature))(pred)
        outputs.append(y)
        x = y
        #RepeatVector(1)(y)
    
    inference_model = tf.keras.Model(inputs=[x0,a0,c0], outputs=outputs)
    return inference_model

# %%
inference_model = generate_sequence(LSTM_cell, prediction_layer, n_values = vocab_size, n_a = n_a, length = max_len, temperature = 1)
# Out:
# (None, 15889)
# Tensor("lambda_78/lambda_78_Multinomial/sample/Reshape:0", shape=(None, 15889), dtype=float32)
# (None, 1, 15889)
# (None, 15889)
# Tensor("lambda_79/lambda_79_Multinomial/sample/Reshape:0", shape=(None, 15889), dtype=float32)
# (None, 1, 15889)
# (None, 15889)
# Tensor("lambda_80/lambda_80_Multinomial/sample/Reshape:0", shape=(None, 15889), dtype=float32)
# (None, 1, 15889)
# (None, 15889)
# Tensor("lambda_81/lambda_81_Multinomial/sample/Reshape:0", shape=(None, 15889), dtype=float32)
# (None, 1, 15889)
# (None, 15889)
# Tensor("lambda_82/lambda_82_Multinomial/sample/Reshape:0", shape=(None, 15889), dtype=float32)
# (None, 1, 15889)
# (None, 15889)
# Tensor("lambda_83/lambda_83_Multinomial/sample/Reshape:0", shape=(None, 15889), dtype=float32)
# (None, 1, 15889)
# (None, 15889)
# Tensor("lambda_84/lambda_84_Multinomial/sample/Reshape:0", shape=(None, 15889), dtype=float32)
# (None, 1, 15889)
# (None, 15889)
# Tensor("lambda_85/lambda_85_Multinomial/sample/Reshape:0", shape=(None, 15889), dtype=float32)
# (None, 1, 15889)
# (None, 15889)
# Tensor("lambda_86/lambda_86_Multinomial/sample/Reshape:0", shape=(None, 15889), dtype=float32)
# (None, 1, 15889)
# (None, 15889)
# Tensor("lambda_87/lambda_87_Multinomial/sample/Reshape:0", shape=(None, 15889), dtype=float32)
# (None, 1, 15889)
# (None, 15889)
# Tensor("lambda_88/lambda_88_Multinomial/sample/Reshape:0", shape=(None, 15889), dtype=float32)
# (None, 1, 15889)
# (None, 15889)
# Tensor("lambda_89/lambda_89_Multinomial/sample/Reshape:0", shape=(None, 15889), dtype=float32)
# (None, 1, 15889)

# %% [markdown]
# ## Sampling without temperature

# %%
#account for temperature
def one_hot(x):
    x = K.argmax(x)
    x = tf.one_hot(indices=x, depth = vocab_size) 
    x = RepeatVector(1)(x)
    return x

# %%
def inference_model(LSTM_cell, prediction_layer, n_values = vocab_size, n_a = n_a, length = max_len):
    
    x0 = Input(shape=(1, n_values))
    
    a0 = Input(shape=(n_a,), name='a0')
    c0 = Input(shape=(n_a,), name='c0')
    
    a = a0
    c = c0
    x = x0
    
    outputs = []
    
    for t in range(length):
        x = reshape_layer(x)
        a, _, c = LSTM_cell(x, initial_state=[a, c]) #or [c,a]
        y = prediction_layer(a)
        outputs.append(y)
        x = Lambda(one_hot)(y)
    
    inference_model = tf.keras.Model(inputs=[x0,a0,c0], outputs=outputs)
    return inference_model

# %%
LSTM_cell.input
# Out:
# [<tf.Tensor 'reshape/Reshape:0' shape=(None, 1, 15889) dtype=float32>,
#  <tf.Tensor 'c0:0' shape=(None, 500) dtype=float32>,
#  <tf.Tensor 'a0:0' shape=(None, 500) dtype=float32>]

# %%
inference_model = inference_model(LSTM_cell, prediction_layer, n_values = vocab_size, n_a = n_a, length = max_len)

# %% [markdown]
# ## Single output model with temperature

# %%
def sample_vec(prob_vec, temperature):
    #prob_vec = np.array(prob_vec).as_type('float64')
    prob_vec = tf.math.divide(tf.math.log(prob_vec),temperature)
    exp_prob_vec = tf.math.exp(prob_vec)
    p = tf.math.divide(exp_prob_vec, tf.math.reduce_sum(exp_prob_vec)) #normalize
    
    #how in tensorflow?
    probs = tfp.distributions.Multinomial(total_count = 1, probs = p) #draw samples from multinomial dsitribution with p = prob, of given output
    y = K.argmax(probs)
    y = tf.one_hot(indices=y, depth= vocab_size)
    y = RepeatVector(1)(y) 
    return y

# %%
def generate_next(LSTM_cell, prediction_layer, n_values = vocab_size, n_a = n_a, length = max_len):
    
    x0 = Input(shape=(1, n_values))
    
    a0 = Input(shape=(n_a,), name='a0')
    c0 = Input(shape=(n_a,), name='c0')
    
    a = a0
    c = c0
    x = x0
    
    x = reshape_layer(x)
    a, _, c = LSTM_cell(x, initial_state=[a, c]) #or [c,a]
    y = prediction_layer(a)
    
    inference_model = tf.keras.Model(inputs=[x0,a0,c0], outputs=y)
    return inference_model

# %%
inference_model = inference_model(LSTM_cell, prediction_layer, n_values = vocab_size, n_a = n_a, length = max_len)

# %%
x_init = np.zeros((1, 1, vocab_size))
a_init = np.zeros((1, n_a))
c_init = np.zeros((1, n_a))

# %% [markdown]
# ## Prediction

# %%
x_init = np.zeros((1, 1, vocab_size))
a_init = np.zeros((1, n_a))
c_init = np.zeros((1, n_a))

# %%
x_init.shape
# Out:
# (1, 1, 15889)

# %%
def predict_sequence(inference_model = inference_model, x_nit = x_init, a_init = a_init, c_init = c_init):
    predictions = inference_model.predict([x_init, a_init, c_init])
    indices = np.argmax(predictions, axis=-1)
    results = []
    for i in range(max_len):
        results.append(indices[i,0,0])
    
    return results

# %%
index_token = {}
for key, value in token_index.items():
    index_token[value] = key

# %%
#find a way to parametrize with temperature!

def get_haiku():
    pred = predict_sequence(inference_model = inference_model, x_nit = x_init, a_init = a_init, c_init = c_init)
    sequence = []
    for elem in pred:
        sequence.append(index_token[elem])
    for elem in sequence:
        print(elem)

# %%
get_haiku()
# Out:
# within
# /
# I'm
# always
# have
# so
# happy
# and
# been
# never
# never
# so
